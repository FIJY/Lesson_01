# %% [markdown]
# <a href="https://colab.research.google.com/github/FIJY/Lesson_01/blob/master/Copy_of_%D0%9F%D0%B0%D1%80%D1%81%D0%B8%D0%BD%D0%B3_hh_ver3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Парсинг с сайта hh <br>
# Ссылка на видео парсинга hh https://yandex.ru/video/preview/11468178118806870731

# %% [markdown]
# ## Устанавливаем и импортируем библиотеки

# %%
# Устанавливаем библиотеки
# requests для отправки запросов
# BeautifulSoup для разбора полученных данных
# lxml для парсинга
# fake_useragent для создания заголовков
# !pip install requests (requests в colab можно не устанавливать)
# !pip install bs4
# !pip install lxml (lxml в colab можно не устанавливать)
# !pip install fake_useragent
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4) (2.5)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2
# Collecting fake_useragent
#   Downloading fake_useragent-1.5.1-py3-none-any.whl (17 kB)
# Installing collected packages: fake_useragent
# Successfully installed fake_useragent-1.5.1

# %%
# Импортируем библиотеки
import requests
from bs4 import BeautifulSoup
import fake_useragent
import time
import json
import pandas as pd
import re
import csv

# %% [markdown]
# ## Парсинг hh

# %%
# Заходим на hh, выбираем регион (Россия)
# Вводим запрос в поле поиска (например python) в разделе Соискателям
# Переходим на вкладку резюме
# Переходим на вторую страницу, чтобы появился параметр page
# Копируем адрес страницы

# %% [markdown]
# ### Создание параметров поиска резюме, <br>получение ссылки-запроса для последующего парсинга ссылок резюме.  <br><br> Источник параметров поиска <br> https://github.com/EvgenyTerebenin/hh-api/blob/master/docs/resumes_search.md

# %%
# Функция создания ссылки для поиска резюме по заданным параметрам

def ref_search_resume (text: str, what_search = 'normal', list_search = ['full_text'],
                       sorting = 'relevance', date_period = 0, date_min = None,
                       date_max = None, quantity_items = 20, areas = [113],
                       arg_relocation = "living_or_relocation", exp_industry = None,
                       exp_period = 'all_time', job_search = None, age_min = None,
                       age_max = None, age_if = False, employments = None,
                       schedules = None, experiences = None, prof_roles = None,
                       gen = "unknown", gender_if = False, salary_min = None,
                       salary_max = None, currency = "RUB", salary_if = False,
                       countries = None, foto_if = False, vehicle_if = False,
                       educations = None, universities = None, ver_skills = None,
                       key_skills = None, work_countries = None,
                       driver_types = None, languages = None,
                       verif_languages = None):

  '''
  Функция создания ссылки для поиска резюме по заданным параметрам.

  :text: Слово или фраза для поиска резюме.

  :what_search = 'normal': Какие слова использовать в поиске
  "Все слова": normal,
  "Любое из слов": any,
  "Точная фраза": phrase,
  "Не встречаются": except

  :list_search = ['full_text']: Где искать указанные слова
  "Везде": full_text,
  "В названии резюме": position,
  "В образовании": education,
  "В ключевых навыках": keywords,
  "В опыте работы": workplaces
  При уточнении можно подавать несколько, списком, но не более трех,
  иначе будет вариант "Везде".

  :sorting = 'relevance': Способ сортировки списка резюме.
  "По дате изменения": publication_time,
  "По убыванию зарплат": salary_desc,
  "По возрастанию зарплаты": salary_asc,
  "По соответствию": relevance

  :date_period = 0: За какой период искать
  "За все время": 0,
  "За сутки": 1,
  "За последние три дня": 3,
  "За неделю": 7,
  "За месяц": 30,
  "За год": 365

  :date_min = None  date_max = None: Интервал поиска между датами
  Формат указания дат ДД.ММ.ГГГГ

  :quantity_items = 20: Количество резюме на одной странице
  Можно указывать любое количество. Стандартный выбор: 20, 50, 70, 100

  :areas = [113]: Регион поиска
  Можно выбирать несколько, подается список кодов регионов
  Источник https://api.hh.ru/areas
  Обозначения некоторых регионов:
  Россия: 113,
  Москва: 1, Московская область: 2019,
  Санкт-Петербург: 2, Ленинградская область: 145,
  Екатеринбург: 3, Свердловская область: 1261,
  Новосибирск: 4, Новосибирская область: 1202,
  Нижний Новгород: 66, Красноярск: 54, Челябинск: 104, Самара: 78, Уфа: 99,
  Краснодар: 53, Ростов-на-Дону: 76, Омск: 68, Воронеж: 26, Пермь: 72, Волгоград: 24,
  Татарстан: 1624, Казань: 88

  :arg_relocation = "living_or_relocation": Переезд
  Источник
  https://api.hh.ru/openapi/redoc#tag/Obshie-spravochniki/operation/get-dictionaries
  Варианты, подается один из вариантов:
  "living_or_relocation" - Живут в указанном регионе или готовы переехать в него,
  "living" - Живут в указанном регионе,
  "living_but_relocation" - Живут в указанном регионе и готовы к переезду куда-либо,
  "relocation" - "Не живут в указанном регионе, но готовы переехать в него"

  :exp_industry = None: Опыт работы в отрасли
  Указывается требуемая отрасль;
  По умолчанию выбраны все отрасли
  Можно выбирать несколько, подается списком кодов отраслей
  Источник https://api.hh.ru/industries
  "Информационные технологии, системная интеграция, интернет": "7",
  включает в себя:
  "Интернет-провайдер": "7.538",
  "Системная интеграция,  автоматизации технологических и
  бизнес-процессов предприятия, ИТ-консалтинг": "7.539",
  "Разработка программного обеспечения": "7.540",
  "Интернет-компания (поисковики, платежные системы, соц.сети,
  информационно-познавательные и развлекательные ресурсы,
  продвижение сайтов и прочее)": "7.541"

  :exp_period = 'all_time': Период работы в отрасли, указывается вместе с опытом работы
  Источник
  https://api.hh.ru/openapi/redoc#tag/Poisk-rezyume/operation/search-for-resumes
  Варианты, выбирается один из вариантов:
  "all_time" - за всё время работы;
  "last_year" - за последний год;
  "last_three_years" - за последние 3 года;
  "last_six_years" - за последние 6 лет

  :job_search = None: Статус поиска работы
  Варианты, можно выбирать несколько, подается списком:
  "unknown" - Без статуса поиска;
  "not_looking_for_job" - Не ищет работу;
  "looking_for_offers" - Рассматривает предложения;
  "active_search" - Активно ищет работу;
  "has_job_offer" - Предложили работу, решает;
  "accepted_job_offer" - Вышел на новое место

  :age_min = None  age_max = None: Возраст, от и до
  :age_if = False: Найти резюме только с возрастом
  (по умолчанию фильтр отсутствует)

  :employments = None: Тип занятости
  По умолчанию не указан
  Варианты, можно выбирать несколько, подается списком:
  "full" - Полная занятость;
  "part" - Частичная занятость;
  "project" - Проектная работа;
  "probation" - Стажировка;
  "volunteer" - Волонтерство

  :schedules = None: График работы
  По умолчанию не указан
  Варианты, можно выбирать несколько, подается списком:
  "fullDay" - Полный день;
  "remote" - Удаленная работа;
  "flexible" - Гибкий график;
  "shift" - Сменный график;
  "flyInFlyOut" - Вахтовый метод

  :experiences = None: Опыт работы
  По умолчанию не указан
  Варианты, можно выбирать несколько, подается списком:
  "moreThan6" - Более 6 лет;
  "between3And6" - От 3 до 6 лет;
  "noExperience" - Нет опыта;
  "between1And3" - От 1 года до 3 лет

  :prof_roles = None: Специализации
  По умолчанию не указаны
  Перечень кодов специализаций (направление "Информационные технологии"),
  можно выбирать несколько, подается список кодов:
  Источник https://api.hh.ru/professional_roles
  "BI-аналитик, аналитик данных": 156,
  "DevOps-инженер": 160,
  "Аналитик": 10,
  "Арт-директор, креативный директор": 12,
  "Бизнес-аналитик": 150,
  "Гейм-дизайнер": 25,
  "Дата-сайентист": 165,
  "Дизайнер, художник": 34,
  "Директор по информационным технологиям (CIO)": 36,
  "Менеджер продукта": 73,
  "Методолог": 155,
  "Программист, разработчик": 96,
  "Продуктовый аналитик": 164,
  "Руководитель группы разработки": 104,
  "Руководитель отдела аналитики": 157,
  "Руководитель проектов": 107,
  "Сетевой инженер": 112,
  "Системный администратор": 113,
  "Системный аналитик": 148,
  "Системный инженер": 114,
  "Специалист по информационной безопасности": 116,
  "Специалист технической поддержки": 121,
  "Тестировщик": 124,
  "Технический директор (CTO)": 125,
  "Технический писатель": 126,
  "Другое": 40

  :gen = "unknown": Пол
  "unknown" - не имеет значения;
  "male" - мужской;
  "female" - женский

  :gender_if = False: Показать резюме с указанием пола
  По умолчанию фильтр отсутствует

  :salary_min = None: Зарплата от
  :salary_max = None: Зарплата до
  :currency = "RUB": Валюта
  Можно задать в евро EUR или в долларах USD

  :salary_if = False: Показать резюме только где указан доход
  По умолчанию фильтр отсутствует

  :countries = None: Гражданство, страна
  Перечень некоторых кодов стран, можно выбирать несколько, подается список кодов:
  Источник https://api.hh.ru/areas/countries
  Россия: 113,
  Беларусь: 16,
  Китай: 50,
  Греция: 213,
  Другое: 6868

  :foto_if = False  vehicle_if = False: Есть фото, автомобиль
  По умолчанию фильтры отсутствуют

  :educations = None: Образование
  Перечень видов образования, можно выбирать несколько, подается список названий:
  "Среднее": secondary,
  "Среднее специальное": special_secondary,
  "Незаконченное высшее": unfinished_higher,
  "Бакалавр": bachelor,
  "Магистр": master,
  "Высшее": higher,
  "Кандидат наук": candidate,
  "Доктор наук": doctor

  :universities = None: Учебное заведение
  Перечень кодов некоторых учебных заведений, можно выбирать несколько,
  подается список кодов:
  Источник https://app.psal.ru/api/university/
  "МГУ": 39144,
  "Национальный исследовательский университет ИТМО": 39872,
  "НИЯУ МИФИ": 39650,
  "МГТУ им. Н.Э. Баумана": 38921

  :ver_skills = None: Подтвержденные навыки
  Перечень кодов навыков, можно выбирать несколько, подается список кодов:
  "Python": 1114,
  "MS Excel": 845,
  "SQL": 1252,
  "Git": 3215,
  "HTML": 598,
  "ООП": 2350,
  "JavaScript": 674,
  "Agile Project Management": 998,
  "Scrum": 3193,
  "Копирайтинг": 2097,
  "AutoCAD": 153

  :key_skills = None: Ключевые навыки
  Перечень кодов навыков, можно выбирать несколько, подается список кодов:
  'Python': 1114, 'SQL': 1252, 'Git': 3215, 'Linux': 730, 'Английский язык': 5488,
  'HTML': 598, 'MS Excel': 845, 'JavaScript': 674, 'Работа в команде': 4118,
  'MySQL': 893, 'PostgreSQL': 1063, 'MS PowerPoint': 866, 'C++': 231, 'CSS': 351,
  'Управление проектами': 2924, 'ООП': 2350, 'Пользователь ПК': 3864,
  'Adobe Photoshop': 87, 'Java': 3093, 'Организаторские навыки': 2366,
  'Грамотная речь': 1827, 'C#': 230, 'HTML5': 7161, 'Ведение переговоров': 1691,
  'PHP': 3750, 'Работа с большим объемом информации': 6958, 'C/C++': 144745,
  'MS Word': 883, 'Деловая переписка': 1855, 'Django Framework': 416,
  'Atlassian Jira': 142, 'Анализ данных': 1534, 'MS SQL': 871,
  'Аналитическое мышление': 14886, 'MATLAB': 791, 'Bash': 4070, 'CSS3': 3512,
  'Деловое общение': 1857, 'Математическая статистика': 2190, 'MS Outlook': 860,
  'AutoCAD': 153, 'Data Analysis': 372, 'jQuery': 687,
  'Управление персоналом': 2917, 'Scrum': 3193, 'Базы данных': 8540,
  'Работа с базами данных': 17049, 'Проведение презентаций': 2514,
  'Деловая коммуникация': 1853, 'Agile Project Management': 99

  :work_countries = None: Разрешение на работу, страна
  Источник https://api.hh.ru/areas/countries
  Россия: 113,
  Беларусь: 16,
  Китай: 50,
  Греция: 213,
  Другое: 6868

  :driver_types = None: Категория прав
  Перечень категорий, можно выбирать несколько, подается список категорий:
  B, C, A, BE, D, E, CE, DE, Tm (трамвай), Tb (троллейбус)

  :languages = None: Знание языков, уровень
  Можно выбирать несколько, подается список языков
  Перечень некоторых языков:
  Источник https://api.hh.ru/languages
  "Русский": rus, 34;
  "Английский": eng, 57;
  "Французский": fra, 59;
  "Немецкий": deu, 58;
  "Белорусский": bel, 7;
  "Китайский": zho, 20
  С языком указывается уровень владения, например "eng.a1"
  Перечень уровней владения языком:
  a1 - Начальный, a2 - Элементарный,
  b1 - Средний, b2 - Средне-продвинутый,
  c1 - Продвинутый, c2 - В совершенстве,
  l1 - Родной язык

  :verif_languages = None: Подтвержденные знания
  (указываются только по английскому языку)
  Перечень кодов подтвержденных знаний:
  "a1 Начальный": 57.1;
  "a2 Элементарный": 57.2;
  "b1 Средний": 57.3;
  "b2 Средне-продвинутый": 57.4;
  "c1 Продвинутый": 57.5;
  "c2 В совершенстве": 57.6
  '''
  # Слово/фраза для поиска резюме
  # Перед подачей в url заменим в text пробелы и другие символы (,;) на url-коды
  text = text.replace(" ", "+").replace(",", "%2C").replace(";", "%3B")

  # Какие слова использовать в поиске
  # what_search = 'any'
  # what_search = 'phrase'
  # what_search = 'except'
  logic = f'&logic={what_search}'

  # Где искать указанные слова
  # list_search = ['keywords', 'position']
  # list_search = ['keywords', 'position', 'education', 'workplaces']
  # list_search = ['keywords']
  if (len(list_search) < 4):
    where_search = '%2C'.join(list_search)
  else:
    where_search = 'full_text'
  pos = f'&pos={where_search}'

  # Способ сортировки списка резюме
  # sorting = 'salary_desc'
  order_by = f'&order_by={sorting}'

  # За какой период искать
  # date_period = 30

  # Интервал поиска между датами
  # date_min = '01.03.2024'
  # date_max = '15.03.2024'
  if (date_min and date_max):
    search_period = f'&search_period=-1&date_from={date_min}&date_to={date_max}'
  else:
    search_period = f'&search_period={date_period}'

  # Количество резюме на одной странице
  # quantity_items = 5
  items_on_page = f'&items_on_page={quantity_items}'

  # Регион поиска
  # areas = [113, 4]
  area = ''.join(f'&area={region}' for region in areas)

  # Переезд
  # arg_relocation = "living"
  relocation = f'&relocation={arg_relocation}'

  # Опыт работы в отрасли
  # exp_industry = [7] # Подается списком кодов отраслей
  # exp_industry = [7.538, 7.540, 7.541]
  filter_exp_industry = ''
  if exp_industry:
    filter_exp_industry = ''.join(f'&filter_exp_industry={exp_industry:.3f}'
                                  if isinstance(exp_industry, float)
                                  else f'&filter_exp_industry={int(exp_industry)}'
                                  for exp_industry in exp_industry)

  # Период опыта работы в отрасли
  # exp_period = "last_year"
  filter_exp_period = f'&filter_exp_period={exp_period}'

  # Статус поиска работы
  # job_search = ["looking_for_offers", "has_job_offer"]
  job_search_status = ''
  if job_search:
    job_search_status = ''.join(f'&job_search_status={search}'
                                for search in job_search)

  # Возраст
  # age_min = 35
  # age_max = 45
  # age_if = True
  age_from = ''
  age_to = ''
  label_age = ''
  if age_min: age_from = f'&age_from={age_min}'
  if age_max: age_to = f'&age_to={age_max}'
  if age_if: label_age = f'&label=only_with_age'

  # Тип занятости
  # employments = ['part', 'probation']
  employment = ''
  if employments:
    employment = ''.join(f'&employment={empl}' for empl in employments)

  # График работы
  # schedules = ['remote', 'flexible']
  schedule = ''
  if schedules:
    schedule = ''.join(f'&schedule={sched}' for sched in schedules)

  # Опыт работы
  # experiences = ['between1And3']
  experience = ''
  if experiences:
    experience = ''.join(f'&experience={exper}' for exper in experiences)

  # Специализации
  # prof_roles = [96, 40, 156]
  professional_role = ''
  if prof_roles:
    professional_role = ''.join(f'&professional_role={prof_role}'
                                for prof_role in prof_roles)

  # Пол
  # gen = "male"
  # gen = "female"
  # gender_if = True
  gender = f'&gender={gen}'
  label_gender = ''
  if gender_if: label_gender = f'&label=only_with_gender'

  # Уровень дохода
  # salary_min = 500
  # salary_max = 1000
  # currency = 'EUR'
  # currency = 'USD'
  # salary_if = True
  salary_from = ''
  salary_to = ''
  label_salary = ''
  currency_code = ''
  if currency in ['EUR', 'USD']: currency_code = f'&currency_code={currency}'
  if salary_min: salary_from = f'&salary_from={salary_min}'
  if salary_max: salary_to = f'&salary_to={salary_max}'
  if salary_if: label_salary = f'&label=only_with_salary'

  # Гражданство, страна
  # countries = [113, 16]
  citizenship = ''
  if countries:
    citizenship = ''.join(f'&citizenship={country}' for country in countries)

  # Есть фото, есть  автомобиль
  # foto_if = True
  # vehicle_if = True
  label_foto = ''
  label_vehicle = ''
  if foto_if: label_foto = f'&label=only_with_photo'
  if vehicle_if: label_vehicle = f'&label=only_with_vehicle'

  # Образование
  # educations = ['higher', 'candidate']
  education_level = ''
  if educations:
    education_level = ''.join(f'&education_level={education}'
                              for education in educations)

  # Учебное заведение
  # universities = [39872, 39650]
  university = ''
  if universities:
    university = ''.join(f'&university={univer}' for univer in universities)

  # Подтвержденные навыки
  # ver_skills = [1114, 845, 2350]
  verified_skills = ''
  if ver_skills:
    verified_skills = ''.join(f'&verified_skills={verif_skill}'
                              for verif_skill in ver_skills)

  # Ключевые навыки
  # key_skills = [3093, 6958, 14886, 1114]
  skill = ''
  if key_skills:
    skill = ''.join(f'&skill={key_skill}' for key_skill in key_skills)

  # Разрешение на работу, страна
  # work_countries = [16, 213]
  work_ticket = ''
  if work_countries:
    work_ticket = ''.join(f'&work_ticket={work_country}'
                          for work_country in work_countries)

  # Категория прав
  # driver_types = ['B', 'C']
  driver_license_types = ''
  if driver_types:
    driver_license_types = ''.join(f'&driver_license_types={type_drive}'
                                   for type_drive in driver_types)

  # Знание языков, уровень
  # Дополнительно по английскому языку можно указать подтвержденные знания
  # languages = ['rus.l1', 'bel.c2', 'eng.c1', 'zho.b1']
  # verif_languages = '57.5'
  language = ''
  if languages:
    language = ''.join(f'&language={lang}' for lang in languages)
  verified_languages = ''
  if languages:
    verified_languages = f'&verified_languages={verif_languages}'

  # Создаем ссылку для поиска резюме по заданным параметрам
  base_url=\
  f"https://hh.ru/search/resume?text={text}{area}&isDefaultArea=true\
&exp_period=all_time{logic}{pos}{order_by}{search_period}{items_on_page}{relocation}\
{filter_exp_industry}{filter_exp_period}{job_search_status}{age_from}{age_to}\
{label_age}{employment}{schedule}{experience}{professional_role}{gender}\
{label_gender}{currency_code}{salary_from}{salary_to}{label_salary}\
{citizenship}{label_foto}{label_vehicle}{education_level}{university}\
{verified_skills}{skill}{work_ticket}{driver_license_types}{language}\
{verified_languages}"

  return base_url

# %% [markdown]
# ### Парсинг ссылок резюме

# %%
# Получаем ссылку-запрос для последующего парсинга ссылок резюме

# Для примера взято ключевое слово для поиска "python"
# и статус соискателя "рассматривает предложения / активно ищет работу"
base_url = ref_search_resume('python')
base_url
# Out:
# 'https://hh.ru/search/resume?text=python&area=113&isDefaultArea=true&exp_period=all_time&logic=normal&pos=full_text&order_by=relevance&search_period=0&items_on_page=20&relocation=living_or_relocation&filter_exp_period=all_time&gender=unknown'

# %%
# # Проверим работу функции
# base_url = ref_search_resume('python')

# base_url

# %%
# Создаем объект для передачи заголовка
# Создадим юзер-агента, общего для всех запросов
ua = fake_useragent.UserAgent()

# %%
# Функция для получения ссылок по запросу
def get_links(base_url):

  data = requests.get(
      url=base_url,
      headers = {"user-agent":ua.random})

  # Если произошла ошибка, выходим из функции
  if data.status_code != 200:
    print(f"Ошибка запроса: HTTP {data.status_code}")
    return

  # В переменную soup передаем содержание полученной страницы
  soup = BeautifulSoup(data.content, "lxml")
  # Найдем количество страниц
  # Внизу открытой страницы hh находим количество страниц 250; нажимаем правой кнопкой мыши и далее "Проверить"
  # В открывшемся справа окне, вверху нажимаем кнопку проверить и выбираем количество страниц (250)
  # Находим div class = "pager", и вводим его в attrs
  # Далее надо найти все "span" и взять последний, т.к. там указано 250
  # Далее у последнего span надо получить ссылку "a"
  # В ссылке надо взять "span", и в "span" взять текст
  # Полученное значение переводим в int
  try:
    page_count = int(soup.find("div", attrs={"class":"pager"}).find_all("span",recursive=False)[-1].find("a").find("span").text)
  except Exception as e:
    print("Ошибка при получении количества страниц: ", e)
    return

  for page in range(page_count):
    try:
      # Создаем заголовок и передаем туда случайный заголовок из созданного объекта
      # В запрос передаем страницу
      data = requests.get(
        url=f"{base_url}&page={page}",
        headers = {"user-agent":ua.random}
      )

      if data.status_code != 200:
        print(f"Пропуск страницы {page} из-за ошибки HTTP {data.status_code}")
        continue
      soup = BeautifulSoup(data.content, "lxml")
      # Выбираем на hh любое резюме, нам нужна ссылка "a", у нее нужен атрибут "data-qa"; этот атрибут вставляем в soup
      # Проходим по всем ссылкам
      for a in soup.find_all("a", attrs={"data-qa":"serp-item__title"}):
        # в каждой ссылке "a" нам нужен адрес сайта в "attrs"
        # в адресе сайта нужно всё до знака "?", поэтому разбиваем ссылку по знаку "?" и берем первый элемент
        yield f"https://hh.ru{a.attrs['href'].split('?')[0]}"
    except Exception as e:
      print(f"Ошибка при обработке страницы {page}: {e}")
    time.sleep(1)

# %%
# Полученные ссылки соберем в список link_resume
# Для примера спарсил ссылки только с одной страницы
link_resume = [a for a in get_links(base_url)]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Записываем полученные ссылки в csv-файл
with open(
    '/content/drive/MyDrive/Practice2/link_resume.csv',
    'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    for resume in link_resume:
        writer.writerow([resume])  # Каждая ссылка записывается в новую строку

# %%
# Прочитаем ссылки из файла csv и сохраним в переменную link_resume_from_csv
with open('/content/drive/MyDrive/Practice2/link_resume.csv', 'r') as link_csv:
  link_resume_from_csv = [row[0] for row in csv.reader(link_csv)]

# %%
link_resume_from_csv
# Out:
# ['https://hh.ru/resume/564d2d4d00090608d70039ed1f497074436c4e',
#  'https://hh.ru/resume/0de1b45d0008b61e070039ed1f6d6f4e4e4b43',
#  'https://hh.ru/resume/5368145600030b31430039ed1f495a32686566',
#  'https://hh.ru/resume/d0f1b2650008cab3a10039ed1f625374695754',
#  'https://hh.ru/resume/f241842900057704840039ed1f314d56754168',
#  'https://hh.ru/resume/b5bd1ef6000917804e0039ed1f483466796348',
#  'https://hh.ru/resume/abbff3eb00073b3a000039ed1f5332314a5056',
#  'https://hh.ru/resume/a984f6330008851b520039ed1f6f635430414b',
#  'https://hh.ru/resume/e7b4bf0a0008e381da0039ed1f38766a646b64',
#  'https://hh.ru/resume/b20968c600072c00690039ed1f696f39643366',
#  'https://hh.ru/resume/cc8ef52f0007dfd4660039ed1f576e5744344e',
#  'https://hh.ru/resume/f2aac92300042a56e90039ed1f566462474c36',
#  'https://hh.ru/resume/41a6d9c900092a94960039ed1f7a306a5a3737',
#  'https://hh.ru/resume/ed8d5f6b00022ee4d60039ed1f32384f6f706e',
#  'https://hh.ru/resume/a5c139a60005a5d37f0039ed1f354a786c326a',
#  'https://hh.ru/resume/fed3ec5500072fa70a0039ed1f455951653241',
#  'https://hh.ru/resume/a9b216270008593e220039ed1f487857776a59',
#  'https://hh.ru/resume/356ac7bd0009025a5a0039ed1f61316e526c4d',
#  'https://hh.ru/resume/3409b90900090eb52b0039ed1f684e39706343',
#  'https://hh.ru/resume/62891cf40002dbdbd10039ed1f636a67527039',
#  'https://hh.ru/resume/87569880000575825b0039ed1f73314d437372',
#  'https://hh.ru/resume/429d47d9000864a3e30039ed1f6352654d3831',
#  'https://hh.ru/resume/2756fa070003af688e0039ed1f4f4777794744',
#  'https://hh.ru/resume/f99b26a400051c40d30039ed1f30674d743051',
#  'https://hh.ru/resume/8f19dc5e0008258e1f0039ed1f774738337475',
#  'https://hh.ru/resume/afd7b48600073fef090039ed1f617168574d76',
#  'https://hh.ru/resume/b3a288f10008c6c3030039ed1f73354b594d4c',
#  'https://hh.ru/resume/bb63f3ee00083dce920039ed1f63756534764e',
#  'https://hh.ru/resume/93c0f10f000281b6dd0039ed1f563447766a49',
#  'https://hh.ru/resume/35baae0200090d61af0039ed1f6856646c3855',
#  'https://hh.ru/resume/7b1a872100086178440039ed1f61766c623747',
#  'https://hh.ru/resume/aa43b1480008f11bc60039ed1f544a6a6c374e',
#  'https://hh.ru/resume/bae047b10008ffe5fd0039ed1f797235564b54',
#  'https://hh.ru/resume/15a2b1840005080b2d0039ed1f744e484e3976',
#  'https://hh.ru/resume/d1a2c97e0007e6a09e0039ed1f63586c65394a',
#  'https://hh.ru/resume/b510943000063ebd7f0039ed1f466a5a797a47',
#  'https://hh.ru/resume/c9d17df300061fd3500039ed1f315777594737',
#  'https://hh.ru/resume/d9109acb00092bd78d0039ed1f4a6f65616e73',
#  'https://hh.ru/resume/cf75ec080007eeefb80039ed1f477730353642',
#  'https://hh.ru/resume/d13c61fd0008b0e27e0039ed1f754a4f457559',
#  'https://hh.ru/resume/a11f76d6000381f9230039ed1f61464b6c5a78',
#  'https://hh.ru/resume/06425d3f0007674b5f0039ed1f4c31746b5764',
#  'https://hh.ru/resume/0eea2b3f00041dfee10039ed1f6c6859333147',
#  'https://hh.ru/resume/1b5ba6710007cb17750039ed1f7234674e554f',
#  'https://hh.ru/resume/07e56a8b0008d08c3a0039ed1f31796b686141',
#  'https://hh.ru/resume/f44e504800074dec2c0039ed1f673178754552',
#  'https://hh.ru/resume/8f7a1fb40000cec9f20039ed1f7973597a346f',
#  'https://hh.ru/resume/35e67801000823a2df0039ed1f695a50713274',
#  'https://hh.ru/resume/5fd266c500046f37000039ed1f345842644a61',
#  'https://hh.ru/resume/563d3c64000832208a0039ed1f4579564d7643',
#  'https://hh.ru/resume/c90def7d00039afa080039ed1f59546b6f5642',
#  'https://hh.ru/resume/a904b9fc000638a8440039ed1f395a4a48754e',
#  'https://hh.ru/resume/7b78a9270002a8e4c90039ed1f36674779346c',
#  'https://hh.ru/resume/a12604080008bae87d0039ed1f4f67766d3831',
#  'https://hh.ru/resume/0c5e449600051014180039ed1f383947426434',
#  'https://hh.ru/resume/4afa57f30005d553d80039ed1f653075307a78',
#  'https://hh.ru/resume/4d774bcb000905262b0039ed1f763935703458',
#  'https://hh.ru/resume/f8096f4c00060364450039ed1f633451494b35',
#  'https://hh.ru/resume/f47cb89f0008a058320039ed1f586c51494d52',
#  'https://hh.ru/resume/9f0acdee00038e9ea30039ed1f3632746c7938',
#  'https://hh.ru/resume/2669f54b00086fd8ec0039ed1f484a63523745',
#  'https://hh.ru/resume/32619fe30003da5fbe0039ed1f3268574e6c51',
#  'https://hh.ru/resume/833c2b880008ebad7b0039ed1f46574230586c',
#  'https://hh.ru/resume/3a5c22850009188db60039ed1f613563757448',
#  'https://hh.ru/resume/e386b148000627531b0039ed1f6a324f733165',
#  'https://hh.ru/resume/7f9474670002ddf9100039ed1f766677705a37',
#  'https://hh.ru/resume/b52b89a90000c08b140039ed1f686371713732',
#  'https://hh.ru/resume/9464d889000879aad00039ed1f4b3271474a37',
#  'https://hh.ru/resume/cd10011e00088d37c50039ed1f647a4c313930',
#  'https://hh.ru/resume/a17bc24c0001584c6e0039ed1f47646f305549',
#  'https://hh.ru/resume/55c8073b00075c94a20039ed1f713559754373',
#  'https://hh.ru/resume/6d0ba88700088063530039ed1f395038447932',
#  'https://hh.ru/resume/8425242c00010f3af80039ed1f346b34554d6c',
#  'https://hh.ru/resume/9843f9c1000337129c0039ed1f764e72735037',
#  'https://hh.ru/resume/6a9abec70008de01cc0039ed1f36445164474d',
#  'https://hh.ru/resume/a49ef7f300088e0a7f0039ed1f595645344371',
#  'https://hh.ru/resume/b60696f4000587d39d0039ed1f56476e394858',
#  'https://hh.ru/resume/402f51d40007e022640039ed1f366a4c4e5066',
#  'https://hh.ru/resume/058de59b0006301df60039ed1f425250566451',
#  'https://hh.ru/resume/3150e83a0002a8a5400039ed1f326176436b56',
#  'https://hh.ru/resume/91d13aca00084c40690039ed1f326e68617845',
#  'https://hh.ru/resume/45c5a9ab000291907c0039ed1f413441533655',
#  'https://hh.ru/resume/5e6d421e0008a682660039ed1f473169673632',
#  'https://hh.ru/resume/911e1cb6000298a7f10039ed1f76476a554866',
#  'https://hh.ru/resume/f05ef37c00031931090039ed1f326f5735545a',
#  'https://hh.ru/resume/83fad8860008d278810039ed1f39595576356b',
#  'https://hh.ru/resume/aeb28d2400084e6f710039ed1f716c64796d72',
#  'https://hh.ru/resume/bdce6b4b0007e92fd40039ed1f6546764f5647',
#  'https://hh.ru/resume/9db1477e00080f5c660039ed1f4250315a3655',
#  'https://hh.ru/resume/44cda8c30002ca0b340039ed1f335030624d6b',
#  'https://hh.ru/resume/ee49403200056cedfa0039ed1f4e7156585655',
#  'https://hh.ru/resume/a9710d2f00071d2b070039ed1f4863596c535a',
#  'https://hh.ru/resume/1acd7b9c00080e17ad0039ed1f6f4c704b6d38',
#  'https://hh.ru/resume/661aaaf80008f3361c0039ed1f496a37674635',
#  'https://hh.ru/resume/7599fb1900035d6a430039ed1f417361676777',
#  'https://hh.ru/resume/e1b52c1d0007ab675d0039ed1f796f35515531',
#  'https://hh.ru/resume/ad6851f70002b329e60039ed1f795864305a67',
#  'https://hh.ru/resume/c5ffe3dc00063777b90039ed1f4f566e546755',
#  'https://hh.ru/resume/1878e1d10003f5c3960039ed1f677538316374',
#  'https://hh.ru/resume/bfe97b0a000189825b0039ed1f5152506e6662',
#  'https://hh.ru/resume/6de6c2ef000225c1530039ed1f6e6b46794137',
#  'https://hh.ru/resume/24b4bb300003a5c7b00039ed1f6a4f4377674a',
#  'https://hh.ru/resume/b7a47b2d000638ac330039ed1f72644b643746',
#  'https://hh.ru/resume/ac88f84b00090f170d0039ed1f34677876384d',
#  'https://hh.ru/resume/add9c8550002b56f0c0039ed1f623954766c78',
#  'https://hh.ru/resume/0f6ee838000619915b0039ed1f706e4d56796e',
#  'https://hh.ru/resume/2519cb44000787fbfb0039ed1f6b466e777755',
#  'https://hh.ru/resume/727c8f18000681af530039ed1f3038636d3058',
#  'https://hh.ru/resume/78c87e2c000612ed6e0039ed1f486a5a775139',
#  'https://hh.ru/resume/dfb3eca30003ec4ee50039ed1f4b5952777544',
#  'https://hh.ru/resume/6346171f00088e045e0039ed1f567641705651',
#  'https://hh.ru/resume/c10b877000073f89f20039ed1f436746614352',
#  'https://hh.ru/resume/7177d32f0008bdb78f0039ed1f61316b304344',
#  'https://hh.ru/resume/b2603fc70003036c380039ed1f6e36696e714b',
#  'https://hh.ru/resume/c7d13dd20003a0b92c0039ed1f42714c36564b',
#  'https://hh.ru/resume/963a9d4600092b24b00039ed1f7046634e4932',
#  'https://hh.ru/resume/674ea34e0003680dd60039ed1f623468553567',
#  'https://hh.ru/resume/f767280a000214d25a0039ed1f6a456c433148',
#  'https://hh.ru/resume/2762cb240002b521550039ed1f644431366678',
#  'https://hh.ru/resume/370aa3ae00089fd0730039ed1f4a666a4e7a70',
#  'https://hh.ru/resume/bdeda2dc00082f9e6b0039ed1f444a354c7035',
#  'https://hh.ru/resume/147b732a0008830dec0039ed1f546e78536f45',
#  'https://hh.ru/resume/f626d86900091e32bb0039ed1f305731356d77',
#  'https://hh.ru/resume/cd62dfc5000819087a0039ed1f516e594a5441',
#  'https://hh.ru/resume/bf77e3cb00059486ef0039ed1f6450737a4231',
#  'https://hh.ru/resume/08c15bfb000904b48d0039ed1f3259414b4579',
#  'https://hh.ru/resume/f62038cf00020890f60039ed1f7774584b3376',
#  'https://hh.ru/resume/0cf6ea94000579e9420039ed1f7a6c65425376',
#  'https://hh.ru/resume/157465eb0007d04f5d0039ed1f4f5672676d45',
#  'https://hh.ru/resume/dc27f9ca000824dbc20039ed1f644478716a78',
#  'https://hh.ru/resume/63e7da970008c027170039ed1f6f674d7a4973',
#  'https://hh.ru/resume/67840f940009076c0f0039ed1f686b74753162',
#  'https://hh.ru/resume/21e43762000889221d0039ed1f706779454a44',
#  'https://hh.ru/resume/10cc07780001edcaf40039ed1f387375377741',
#  'https://hh.ru/resume/dde38eb0000515ee620039ed1f427670763068',
#  'https://hh.ru/resume/e888df2800017cbc810039ed1f57756f376855',
#  'https://hh.ru/resume/d52d3b8d00082e3d0a0039ed1f626162567638',
#  'https://hh.ru/resume/34c1eef3000808ab250039ed1f386d66734b50',
#  'https://hh.ru/resume/e535e1a000061b60180039ed1f4d7836325656',
#  'https://hh.ru/resume/fe490cfb00091d186b0039ed1f654a534d4a6a',
#  'https://hh.ru/resume/bee0660c00080a04f10039ed1f53547a664e75',
#  'https://hh.ru/resume/3a61443c0008ff3c0a0039ed1f6b3752357a74',
#  'https://hh.ru/resume/45907d7300088403e60039ed1f6a4d71364d72',
#  'https://hh.ru/resume/d28a6c3100042724900039ed1f484d484b5a6d',
#  'https://hh.ru/resume/bbec629500075a38cf0039ed1f736548735254',
#  'https://hh.ru/resume/400c79320005c2abb90039ed1f364b4e4c686f',
#  'https://hh.ru/resume/a511c58f00029105c20039ed1f334f6e546c46',
#  'https://hh.ru/resume/0a542c0b0000540eef0039ed1f736563726574',
#  'https://hh.ru/resume/e1f47e0e000693cf660039ed1f666466656474',
#  'https://hh.ru/resume/35855d7f00015db4250039ed1f6e5364477752',
#  'https://hh.ru/resume/272c4b10000451b05b0039ed1f426c7770744b',
#  'https://hh.ru/resume/c5c7829200077c1b1b0039ed1f3754484a6747',
#  'https://hh.ru/resume/592fea160008d7925a0039ed1f72477a6b4444',
#  'https://hh.ru/resume/5c70470f0008951ff40039ed1f393550643341',
#  'https://hh.ru/resume/857d2bf700087025f90039ed1f355036447243',
#  'https://hh.ru/resume/bd338684000909154e0039ed1f6a6478304544',
#  'https://hh.ru/resume/1d8b621900050947af0039ed1f707a37424a6f',
#  'https://hh.ru/resume/32e26e18000828b0c50039ed1f705079504e6c',
#  'https://hh.ru/resume/a121ec2e0008d67b9b0039ed1f30766f334764',
#  'https://hh.ru/resume/ced255db000412d8530039ed1f455152415577',
#  'https://hh.ru/resume/0bcb3cbf0002ddbdd90039ed1f614974473077',
#  'https://hh.ru/resume/2ac263e000042fd1f80039ed1f413462333073',
#  'https://hh.ru/resume/4caac8e80008fd8a130039ed1f305451724743',
#  'https://hh.ru/resume/1e4e315f00083eacdb0039ed1f793646416669',
#  'https://hh.ru/resume/e0340cb00008b196d00039ed1f716675655657',
#  'https://hh.ru/resume/c59a93ed0008cefbed0039ed1f5044434f5476',
#  'https://hh.ru/resume/5fcb52ff00060bff520039ed1f523077713561',
#  'https://hh.ru/resume/77cf03220007e2a9dc0039ed1f304b476f7141',
#  'https://hh.ru/resume/fdc1480d0008ab9e360039ed1f33526c4a6431',
#  'https://hh.ru/resume/985b62460002434c710039ed1f575470707170',
#  'https://hh.ru/resume/734aef8700089792e30039ed1f3539376c7159',
#  'https://hh.ru/resume/a9c4c94a00086df2fa0039ed1f426637717a78',
#  'https://hh.ru/resume/3812016a00085b7f3c0039ed1f4d55574a695a',
#  'https://hh.ru/resume/751610660008bab6870039ed1f70353151724a',
#  'https://hh.ru/resume/3769a4f1000028a4100039ed1f736563726574',
#  'https://hh.ru/resume/adea6ffe0007506d1c0039ed1f344f677a5a37',
#  'https://hh.ru/resume/9a5643ae000856b5400039ed1f685a4d634a75',
#  'https://hh.ru/resume/e308da6a00086704ce0039ed1f487234556346',
#  'https://hh.ru/resume/cb54fcc100059a258c0039ed1f386779354772',
#  'https://hh.ru/resume/1c4975c10003c9cedf0039ed1f4234394a5256',
#  'https://hh.ru/resume/813e676700086d8ec60039ed1f41496e41746f',
#  'https://hh.ru/resume/3907efc90003159f020039ed1f38786837346a',
#  'https://hh.ru/resume/1e5afe3d00024a552f0039ed1f626671463564',
#  'https://hh.ru/resume/d94ec71b00075a6e870039ed1f396664524745',
#  'https://hh.ru/resume/bb471bb3000817f4050039ed1f66564f753556',
#  'https://hh.ru/resume/8a9ab7480004664a0c0039ed1f6a454b726547',
#  'https://hh.ru/resume/f8fa3aa50002062bfb0039ed1f5555514b4c68',
#  'https://hh.ru/resume/36043f3e00082b74570039ed1f5133476c4469',
#  'https://hh.ru/resume/dadcd6870005570f2e0039ed1f6f656b544362',
#  'https://hh.ru/resume/3b77e23100028232e80039ed1f556a6d484f56',
#  'https://hh.ru/resume/717de96500068377530039ed1f6a63454e6656',
#  'https://hh.ru/resume/7f9f77bc00085ddc470039ed1f58613266686a',
#  'https://hh.ru/resume/b2ed434100012a39330039ed1f75455a616777',
#  'https://hh.ru/resume/474b424c0007fbf99e0039ed1f634330573633',
#  'https://hh.ru/resume/e675cbff000368b8e50039ed1f566d61744c46',
#  'https://hh.ru/resume/2cf024cc000880cea40039ed1f6c3854646a49',
#  'https://hh.ru/resume/eb6fe2b6000459c7b10039ed1f6f4e58647945',
#  'https://hh.ru/resume/3a110ee100082705a20039ed1f4e544f544455',
#  'https://hh.ru/resume/b222eb3500090bb9880039ed1f63324b455634',
#  'https://hh.ru/resume/82bfe78f0006d6eb210039ed1f50496357547a',
#  'https://hh.ru/resume/27978b07000897437f0039ed1f667142667756',
#  'https://hh.ru/resume/19b98c430008d2d8510039ed1f6673334e7930',
#  'https://hh.ru/resume/e298f83700081b8e570039ed1f7136314f6674',
#  'https://hh.ru/resume/c22844d10001f1df9b0039ed1f475775564931',
#  'https://hh.ru/resume/ce9884d90004630dc70039ed1f65316c4d564a',
#  'https://hh.ru/resume/2703cbaa00058cd8090039ed1f6c5744566c49',
#  'https://hh.ru/resume/811fcece0004375c840039ed1f797155623677',
#  'https://hh.ru/resume/81e1a85f0007a9bf410039ed1f6a4972775244',
#  'https://hh.ru/resume/8decf40e0006e130e80039ed1f544c54535a42',
#  'https://hh.ru/resume/57b9ee6600087549c70039ed1f3737424d6445',
#  'https://hh.ru/resume/5a6775a50005efe5cf0039ed1f564436343059',
#  'https://hh.ru/resume/c942b77800043c346a0039ed1f5a504e6e5947',
#  'https://hh.ru/resume/1916a323000929c1690039ed1f693966516d61',
#  'https://hh.ru/resume/92c13d620003e070e40039ed1f4b7a6f517a42',
#  'https://hh.ru/resume/359a2f1e0003a6f8ee0039ed1f426449367135',
#  'https://hh.ru/resume/c7ca7de90008726bd70039ed1f6e70625a434d',
#  'https://hh.ru/resume/45a63d2a00091fe4a40039ed1f5a677551734e',
#  'https://hh.ru/resume/f320dacf000409b7240039ed1f6c4a634d734f',
#  'https://hh.ru/resume/5ed06a5900085891700039ed1f314f31477249',
#  'https://hh.ru/resume/e7d0a29a000808f0760039ed1f575374743873',
#  'https://hh.ru/resume/629f4b8e00075c09020039ed1f595979613935',
#  'https://hh.ru/resume/315d4b03000640ccc90039ed1f437351523050',
#  'https://hh.ru/resume/05be7fa80009200b590039ed1f3951476e6f41',
#  'https://hh.ru/resume/4fdde4900006cf18c40039ed1f665279616459',
#  'https://hh.ru/resume/0e6becc00008ddd9090039ed1f4264504d4a6b',
#  'https://hh.ru/resume/1040f8e30006dd294f0039ed1f367868786d59',
#  'https://hh.ru/resume/cc11e2280008e783020039ed1f673155733170',
#  'https://hh.ru/resume/ea5db04a0007f887ff0039ed1f764e4b6a3867',
#  'https://hh.ru/resume/1e7322290008c59b910039ed1f4b6639786b39',
#  'https://hh.ru/resume/1f808d220008b1859b0039ed1f7a755533384e',
#  'https://hh.ru/resume/02a786760008ba288e0039ed1f746139385135',
#  'https://hh.ru/resume/00911ffa0008e38fd40039ed1f547a59725a6e',
#  'https://hh.ru/resume/70c15e6d0002b843010039ed1f435832773257',
#  'https://hh.ru/resume/4bf0dced000800a0010039ed1f4c7a744c5634',
#  'https://hh.ru/resume/164f1c69000519e6b40039ed1f566969794477',
#  'https://hh.ru/resume/846a4fae00071c0dc90039ed1f4b76546c376a',
#  'https://hh.ru/resume/94bce8a30008b5d1b90039ed1f735670416350',
#  'https://hh.ru/resume/36954c350007bf0ef80039ed1f4335476c5549',
#  'https://hh.ru/resume/dc06a4ab00087f022e0039ed1f72693056566a',
#  'https://hh.ru/resume/10bbf18000046374f50039ed1f636e6e7a7039',
#  'https://hh.ru/resume/ed49f91100043ece2e0039ed1f4b48396c3930',
#  'https://hh.ru/resume/78b4f657000823152a0039ed1f736e54657644',
#  'https://hh.ru/resume/277ecf9b000917c3ca0039ed1f71677244795a',
#  'https://hh.ru/resume/55c98247000763dba10039ed1f6b56664a4e79',
#  'https://hh.ru/resume/eeb049010007767f900039ed1f336b32693850',
#  'https://hh.ru/resume/2e7cf4bb00080c60130039ed1f416963584d30',
#  'https://hh.ru/resume/b6c2e6df00071077930039ed1f767341704d42',
#  'https://hh.ru/resume/6dbe519400041408d70039ed1f754d5a38316c',
#  'https://hh.ru/resume/2484acfc000888fb620039ed1f655930534147',
#  'https://hh.ru/resume/31fc59610003ded67e0039ed1f756a62627778',
#  'https://hh.ru/resume/d78afe9f0001a625ee0039ed1f37334e634e64',
#  'https://hh.ru/resume/c2a1ee1700044f6f900039ed1f6f6d4b485962',
#  'https://hh.ru/resume/a0fc25c800089c5f4a0039ed1f723969755030',
#  'https://hh.ru/resume/3036305e00060179f90039ed1f41577352546c',
#  'https://hh.ru/resume/f0aa06c40007ef913d0039ed1f7a5735685873',
#  'https://hh.ru/resume/0c24b9620007dd05620039ed1f44486a6f7079',
#  'https://hh.ru/resume/9172df110003fb69fe0039ed1f35736c767361',
#  'https://hh.ru/resume/25e5b49f000727e1a70039ed1f6138574b724a',
#  'https://hh.ru/resume/fed2d039000809849e0039ed1f757a72514935',
#  'https://hh.ru/resume/410100360008aa620a0039ed1f794976455372',
#  'https://hh.ru/resume/1b2862d10002a780780039ed1f727675476f50',
#  'https://hh.ru/resume/afa811f5000171ae080039ed1f59467335725a',
#  'https://hh.ru/resume/237d1c360008b8e8b20039ed1f315979306b53',
#  'https://hh.ru/resume/1157d913000298395a0039ed1f753836305873',
#  'https://hh.ru/resume/af83232500085dd6470039ed1f535879337868',
#  'https://hh.ru/resume/0e9687060003b604ac0039ed1f68456b58624d',
#  'https://hh.ru/resume/7f910c910002c14a880039ed1f42534c574f65',
#  'https://hh.ru/resume/fb7ea8c800035e24280039ed1f6d5a31676963',
#  'https://hh.ru/resume/688b7cb20008ae0e850039ed1f793067776e54',
#  'https://hh.ru/resume/d24aea9f000579d9e00039ed1f3946576b5433',
#  'https://hh.ru/resume/c831cebb0009139bbf0039ed1f587045436b6e',
#  'https://hh.ru/resume/c19c94c200024d90e40039ed1f5a3445766365',
#  'https://hh.ru/resume/8cefbd750001b22c010039ed1f4979437a6a6c',
#  'https://hh.ru/resume/e4ec9ff300039e5edf0039ed1f633944467647',
#  'https://hh.ru/resume/b534e9dd0001fb7cba0039ed1f45694f626d6b',
#  'https://hh.ru/resume/257ab03e0008d843b10039ed1f53666d77636e',
#  'https://hh.ru/resume/ebc04c1900089e2f920039ed1f6f7479625938',
#  'https://hh.ru/resume/b36e0d350008e780fe0039ed1f6f417479344b',
#  'https://hh.ru/resume/fff6627400083091550039ed1f516d564a5266',
#  'https://hh.ru/resume/ef5dcb300007861e360039ed1f355555565231',
#  'https://hh.ru/resume/ef5dcb300007861e360039ed1f355555565231',
#  'https://hh.ru/resume/ef5ed24e00024338440039ed1f457551695858',
#  'https://hh.ru/resume/33a92daf00086344950039ed1f55326b464444',
#  'https://hh.ru/resume/011ed47b00088b26070039ed1f616b6f6c4358',
#  'https://hh.ru/resume/8668d0750005347d830039ed1f387570454c69',
#  'https://hh.ru/resume/4b8747ac0007c69e1c0039ed1f374d78796c6a',
#  'https://hh.ru/resume/02b65df00009235e3c0039ed1f45353169576a',
#  'https://hh.ru/resume/4a77a11700088f34940039ed1f364a55703552',
#  'https://hh.ru/resume/5dee74f600083cb5450039ed1f6f4c374a3877',
#  'https://hh.ru/resume/ce92f2c10000ebc83b0039ed1f666543473558',
#  'https://hh.ru/resume/fd457d5c000559c40b0039ed1f7152624c3231',
#  'https://hh.ru/resume/5dff33160003c9912d0039ed1f624a474d7770',
#  'https://hh.ru/resume/952069f4000599d0570039ed1f3279426f7a55',
#  'https://hh.ru/resume/6d46c0290007fff2fc0039ed1f79693552774e',
#  'https://hh.ru/resume/6f3634fe00090b28d00039ed1f46707378707a',
#  'https://hh.ru/resume/37f95d9300032863830039ed1f6575484e7647',
#  'https://hh.ru/resume/c74fd55d00067d64a10039ed1f556b65304b78',
#  'https://hh.ru/resume/ce3cd43c00060f80a10039ed1f4841774f7351',
#  'https://hh.ru/resume/6922f8a200075493df0039ed1f6a6b736f5657',
#  'https://hh.ru/resume/0dd8def700075801500039ed1f4d7734467875',
#  'https://hh.ru/resume/12093ccc0001a612bb0039ed1f7032484f7069',
#  'https://hh.ru/resume/0788cc4000039124ae0039ed1f517533507131',
#  'https://hh.ru/resume/1fea57b5000747b17f0039ed1f63526e374278',
#  'https://hh.ru/resume/616d854100063e3e740039ed1f54545469374b',
#  'https://hh.ru/resume/fc977b1c00083e823d0039ed1f496c754c3867',
#  'https://hh.ru/resume/8803f7e300076a57870039ed1f4b7a5a736847',
#  'https://hh.ru/resume/b20787e00003b6474f0039ed1f354f4c624971',
#  'https://hh.ru/resume/33d9eeaf00080c9d770039ed1f34346543394f',
#  'https://hh.ru/resume/d83745570003679a460039ed1f624971666e55',
#  'https://hh.ru/resume/2216de200004bfcec60039ed1f4f6257326d38',
#  'https://hh.ru/resume/0d13982c0008ba97050039ed1f4e4471636f58',
#  'https://hh.ru/resume/43bba735000761ce5b0039ed1f695973533961',
#  'https://hh.ru/resume/7dd6bd880007da75e30039ed1f6b714a756c50',
#  'https://hh.ru/resume/1a4a700b000160f6270039ed1f424f4d46376d',
#  'https://hh.ru/resume/f906fea0000765931d0039ed1f6465454c4565',
#  'https://hh.ru/resume/649f3a2b0000ce1a2e0039ed1f35626939524f',
#  'https://hh.ru/resume/ca1cf2f30009345ed50039ed1f6e5867704438',
#  'https://hh.ru/resume/99f9cc8d0004da4b410039ed1f745946315a53',
#  'https://hh.ru/resume/96efd6ab00080fa5260039ed1f797544546538',
#  'https://hh.ru/resume/b0ddc13d00061ce7170039ed1f436c4f477035',
#  'https://hh.ru/resume/73db557b00080750880039ed1f643552733656',
#  'https://hh.ru/resume/4f1193580005f416200039ed1f687930435041',
#  'https://hh.ru/resume/b32dfa7400084135f60039ed1f4558787a4f6b',
#  'https://hh.ru/resume/0f9dab680008d1c6d90039ed1f4f3450706c70',
#  'https://hh.ru/resume/c3b7c56b00092b41eb0039ed1f4c664a6a6d36',
#  'https://hh.ru/resume/f4f2bed50005a7d6eb0039ed1f4a6d76794c56',
#  'https://hh.ru/resume/4bf784100003ebff3f0039ed1f565a51574b39',
#  'https://hh.ru/resume/14d637880008469c0f0039ed1f743939503472',
#  'https://hh.ru/resume/15b032b30002722ad90039ed1f304f70426674',
#  'https://hh.ru/resume/d050294900090bf67e0039ed1f36324d6d3276',
#  'https://hh.ru/resume/cbbf8da200009f88330039ed1f736563726574',
#  'https://hh.ru/resume/306a826b00059717d60039ed1f4a397174694d',
#  'https://hh.ru/resume/d5eeb65e0008e1b1a20039ed1f434a73464145',
#  'https://hh.ru/resume/521ea6610008a162940039ed1f385551544175',
#  'https://hh.ru/resume/026b8af10003409aba0039ed1f7866676e7553',
#  'https://hh.ru/resume/b9637b2c0008d384c10039ed1f4e4b72516f31',
#  'https://hh.ru/resume/5de0b54f0007e6ae580039ed1f55367270514d',
#  'https://hh.ru/resume/1ec6219000040b76540039ed1f506e5279734c',
#  'https://hh.ru/resume/f5bc19b5000219ab9b0039ed1f725271575663',
#  'https://hh.ru/resume/726679d50007f911200039ed1f4e3431346d44',
#  'https://hh.ru/resume/748568aa0005c395070039ed1f71476b344c48',
#  'https://hh.ru/resume/c93680750007227a150039ed1f594e6c67776d',
#  'https://hh.ru/resume/d303b83400041ab52a0039ed1f5971346c3174',
#  'https://hh.ru/resume/defb751b000597df880039ed1f4b7946433048',
#  'https://hh.ru/resume/115faa9900088041ba0039ed1f6949324d7554',
#  'https://hh.ru/resume/0bcebb21000548b1820039ed1f774c59664b38',
#  'https://hh.ru/resume/d93fd1eb0001f31e500039ed1f757636547954',
#  'https://hh.ru/resume/e7d69e2000010b374c0039ed1f326b50354e54',
#  'https://hh.ru/resume/a0950ae800033c1a7f0039ed1f4949495a746e',
#  'https://hh.ru/resume/6226350c00088750510039ed1f775a50564966',
#  'https://hh.ru/resume/79d001390007c9fa5b0039ed1f636f38353976',
#  'https://hh.ru/resume/e54f6b3d0005d43c4c0039ed1f4b3870625644',
#  'https://hh.ru/resume/84a16c950003abf88d0039ed1f4c506f533937',
#  'https://hh.ru/resume/a55d8d9500052770c90039ed1f35594f4f7963',
#  'https://hh.ru/resume/258c523f00035541440039ed1f687a39654e69',
#  'https://hh.ru/resume/c4bfe6420000aaa0e40039ed1f736563726574',
#  'https://hh.ru/resume/a63fb3270008646b420039ed1f424d79456d32',
#  'https://hh.ru/resume/b99ff2470007374faf0039ed1f677a4b6a6173',
#  'https://hh.ru/resume/409119ae00080340050039ed1f394a33367679',
#  'https://hh.ru/resume/c9d14c5600024b74a20039ed1f636a72505746',
#  'https://hh.ru/resume/30b8107400084e0aa80039ed1f564569797665',
#  'https://hh.ru/resume/70fc3c550003f3c5f30039ed1f495144377077',
#  'https://hh.ru/resume/0ec99e4600019566b50039ed1f774571363659',
#  'https://hh.ru/resume/e6105c6f000203aaf00039ed1f76615a614168',
#  'https://hh.ru/resume/d311dbe30008ecf7c90039ed1f4f69556b3954',
#  'https://hh.ru/resume/bf06b6cc00075c05620039ed1f4d7653743874',
#  'https://hh.ru/resume/0c35cb180007db22660039ed1f735679547955',
#  'https://hh.ru/resume/1a3159c20006c373b40039ed1f714b3947687a',
#  'https://hh.ru/resume/d44f89270003ec7b450039ed1f45574d394141',
#  'https://hh.ru/resume/e2d757e800072a4e3a0039ed1f533945373745',
#  'https://hh.ru/resume/6f16848200044260230039ed1f535954734442',
#  'https://hh.ru/resume/c0e48b5a0008fbf24e0039ed1f396d79794f70',
#  'https://hh.ru/resume/63056d590002b6f1240039ed1f45464c726276',
#  'https://hh.ru/resume/d3ad4fc000036736420039ed1f45426f7a6450',
#  'https://hh.ru/resume/b8875f81000206da980039ed1f4730714c5353',
#  'https://hh.ru/resume/11aa21fd00079632c50039ed1f457268724964',
#  'https://hh.ru/resume/fb71804b00005040e50039ed1f736563726574',
#  'https://hh.ru/resume/1e89238800092156a10039ed1f314a59664746',
#  'https://hh.ru/resume/c00e33bb0003d6244e0039ed1f635a64357542',
#  'https://hh.ru/resume/b6c3e0e50005dc35040039ed1f553858314c4f',
#  'https://hh.ru/resume/faa161be00070a81f80039ed1f537946535975',
#  'https://hh.ru/resume/f809cf5800063a0dc00039ed1f50616d715438',
#  'https://hh.ru/resume/61403f200008ad47370039ed1f785346317552',
#  'https://hh.ru/resume/732b5dd400039a71f80039ed1f59534a7a5270',
#  'https://hh.ru/resume/b4796328000308c8400039ed1f564337563171',
#  'https://hh.ru/resume/3eb752080008cfd2b50039ed1f315232485044',
#  'https://hh.ru/resume/15bd3fab00033e7c890039ed1f784b69566730',
#  'https://hh.ru/resume/8ccb10690007e59d320039ed1f464c4c557344',
#  'https://hh.ru/resume/1dcd17c90008e03fde0039ed1f6e784434476a',
#  'https://hh.ru/resume/aa87220600077da8250039ed1f4d394c626e6f',
#  'https://hh.ru/resume/c333512200092d4ccb0039ed1f435038625130',
#  'https://hh.ru/resume/d053b49a0008b6eee40039ed1f635166485348',
#  'https://hh.ru/resume/af49083a00047ebed50039ed1f476d3162694f',
#  'https://hh.ru/resume/5b687b800008cfcdb30039ed1f6e364f583862',
#  'https://hh.ru/resume/461f5b2600013b1b540039ed1f434a5434704e',
#  'https://hh.ru/resume/63c295560002c552520039ed1f416c79346a4d',
#  'https://hh.ru/resume/f6d1105200066c8f250039ed1f4f7267417238',
#  'https://hh.ru/resume/68ecc37f000252395b0039ed1f7247304f5333',
#  'https://hh.ru/resume/fdf3b270000630622c0039ed1f4f614c695a6e',
#  'https://hh.ru/resume/d9182d200008ab1f1b0039ed1f4d677a346d6a',
#  'https://hh.ru/resume/8c7dc78f00046161620039ed1f6f5532557937',
#  'https://hh.ru/resume/c36f42740007155f5a0039ed1f494976636b6c',
#  'https://hh.ru/resume/22851cb70002bb50480039ed1f69467965386a',
#  'https://hh.ru/resume/ab9120590001e09a980039ed1f6b5370767478',
#  'https://hh.ru/resume/96c81e71000252c4d40039ed1f52614b587559',
#  'https://hh.ru/resume/124f3d7f0008f83bed0039ed1f7a6c674c5273',
#  'https://hh.ru/resume/3765afee000736c3970039ed1f7a4f744f7347',
#  'https://hh.ru/resume/e72bb1f2000720e8140039ed1f444e494c7945',
#  'https://hh.ru/resume/8e8c8f0c0008cc67d40039ed1f6d5042327572',
#  'https://hh.ru/resume/a17c14c80001ad36550039ed1f63367355646d',
#  'https://hh.ru/resume/fa5bdf150005075f9e0039ed1f74685a4c704c',
#  'https://hh.ru/resume/f2e375b900072516710039ed1f57476d783364',
#  'https://hh.ru/resume/b4fe3bb10000ab930f0039ed1f736563726574',
#  'https://hh.ru/resume/c9b99c7100075a82260039ed1f706d31665749',
#  'https://hh.ru/resume/cb115d3e0007eb0ee70039ed1f7a6b55443465',
#  'https://hh.ru/resume/b28b780300034bd2ac0039ed1f4a5459536a43',
#  'https://hh.ru/resume/b95ee5070001a2d5260039ed1f58767a706348',
#  'https://hh.ru/resume/f2f7673d0000a3744c0039ed1f736563726574',
#  'https://hh.ru/resume/806f40a1000328a2a60039ed1f55436f4e4343',
#  'https://hh.ru/resume/b01aa730000590da1b0039ed1f5165486c4139',
#  'https://hh.ru/resume/85f0570a00079ba4ee0039ed1f597648726172',
#  'https://hh.ru/resume/ff788e880007abff5e0039ed1f687a35506669',
#  'https://hh.ru/resume/0a0d973c0008e916390039ed1f4e307a697361',
#  'https://hh.ru/resume/c29963e70003abbd7a0039ed1f366b4a4f5175',
#  'https://hh.ru/resume/d2c0ea89000772693d0039ed1f685041466450',
#  'https://hh.ru/resume/07c694260003e918e40039ed1f387938617136',
#  'https://hh.ru/resume/8390450200085dedcb0039ed1f4941516e3438',
#  'https://hh.ru/resume/17ee32a60008d9a3520039ed1f4e7430553641',
#  'https://hh.ru/resume/711c5fde0006067e800039ed1f66686e544956',
#  'https://hh.ru/resume/a9640fd600020de55b0039ed1f5467635a7261',
#  'https://hh.ru/resume/cf1095240006ea258a0039ed1f464732716353',
#  'https://hh.ru/resume/6c7c79320002b855210039ed1f663769414553',
#  'https://hh.ru/resume/0a28cfea0003740eb30039ed1f375975686c38',
#  'https://hh.ru/resume/153e2e0f0007faa7070039ed1f6b72584d4941',
#  'https://hh.ru/resume/f50813d300078584b00039ed1f653076773839',
#  'https://hh.ru/resume/9ac1de96000365400c0039ed1f7465597a5646',
#  'https://hh.ru/resume/b60ae0a700043334070039ed1f77745a546567',
#  'https://hh.ru/resume/8f786486000364433c0039ed1f395670553633',
#  'https://hh.ru/resume/f77a0efa000299dd770039ed1f32653950566c',
#  'https://hh.ru/resume/83cf3e810007b61c0e0039ed1f697349696478',
#  'https://hh.ru/resume/c37222cb00031edfc60039ed1f516e71325676',
#  'https://hh.ru/resume/c866aa8e00082dd0400039ed1f6a3130776465',
#  'https://hh.ru/resume/a71466fa0007e590a70039ed1f4b534a417664',
#  'https://hh.ru/resume/42bbfd8800075555050039ed1f6f3368555a70',
#  'https://hh.ru/resume/68bae28700017393630039ed1f393379673831',
#  'https://hh.ru/resume/2307f9630003b9e5030039ed1f375544393046',
#  'https://hh.ru/resume/73cdd7620008e63b9d0039ed1f41315a6e304d',
#  'https://hh.ru/resume/59557af7000466dc350039ed1f6764414a4935',
#  'https://hh.ru/resume/84489f0d000911d3f30039ed1f526568777847',
#  'https://hh.ru/resume/7dc01cd3000896d8860039ed1f426735787531',
#  'https://hh.ru/resume/3d8f2cab000128a6fa0039ed1f31416a484977',
#  'https://hh.ru/resume/181bf152000894298b0039ed1f7971366e6b67',
#  'https://hh.ru/resume/dcd80af60008e0559f0039ed1f5141614f376e',
#  'https://hh.ru/resume/cd84de290002df21700039ed1f574d6d705a52',
#  'https://hh.ru/resume/6a8671ce0005311ddd0039ed1f4b79594c5a56',
#  'https://hh.ru/resume/8109d90f0008a381030039ed1f5a7472614361',
#  'https://hh.ru/resume/e87b61fa000781a7a00039ed1f504c336c3833',
#  'https://hh.ru/resume/082d3fde0008e45a280039ed1f357763526679',
#  'https://hh.ru/resume/2b17ee8700042f74640039ed1f424c58675856',
#  'https://hh.ru/resume/1f2743610003ff8b5a0039ed1f41586d46344c',
#  'https://hh.ru/resume/9730fea800064561390039ed1f686d4f614459',
#  'https://hh.ru/resume/5780b07200076d50b50039ed1f4e476e4e526d',
#  'https://hh.ru/resume/af52431e00047c61f20039ed1f463636363232',
#  'https://hh.ru/resume/d40f45a3000922311e0039ed1f366969695757',
#  'https://hh.ru/resume/2035fd960002859a810039ed1f315651686a52',
#  'https://hh.ru/resume/252619870001e92c710039ed1f6f4774587575',
#  'https://hh.ru/resume/6b5c0ae400021968090039ed1f3867666e3332',
#  'https://hh.ru/resume/acc4a2690008b6c4180039ed1f57385353494c',
#  'https://hh.ru/resume/229c4a0d00079582530039ed1f4f694c6f6366',
#  'https://hh.ru/resume/f8a906b600076eb0e30039ed1f4b3147415264',
#  'https://hh.ru/resume/c250cdf8000440cf640039ed1f51427a7a4557',
#  'https://hh.ru/resume/8be648a600086134d50039ed1f47665437646e',
#  'https://hh.ru/resume/5aaf264f0002cb367c0039ed1f5138486f6272',
#  'https://hh.ru/resume/6ec279f00007d3aa630039ed1f534b566d4868',
#  'https://hh.ru/resume/eee9e9c1000618caad0039ed1f6b7542327172',
#  'https://hh.ru/resume/b295078c0004056f840039ed1f4c6736783563',
#  'https://hh.ru/resume/ca0ebfba000914bcc50039ed1f7436557a314b',
#  'https://hh.ru/resume/47ddf04400090568960039ed1f4d524b655655',
#  'https://hh.ru/resume/0905d16800042150440039ed1f666455306f6d',
#  'https://hh.ru/resume/26c247020008db089a0039ed1f674564647647',
#  'https://hh.ru/resume/1a35850a0007569fc10039ed1f484344755834',
#  'https://hh.ru/resume/f83defcd000551d4d90039ed1f7868546b7559',
#  'https://hh.ru/resume/b7c37e5000091397640039ed1f753648704177',
#  'https://hh.ru/resume/2beaf4ee0003f423880039ed1f426c66457a78',
#  'https://hh.ru/resume/7bd2ec580008b97be40039ed1f466f6379694e',
#  'https://hh.ru/resume/36d289dc00028ed23b0039ed1f36675776556e',
#  'https://hh.ru/resume/d88c0b150008c3df440039ed1f577056694132',
#  'https://hh.ru/resume/39c7ce7200031f93320039ed1f324d47775377',
#  'https://hh.ru/resume/b4e325f3000400f3f50039ed1f743472654362',
#  'https://hh.ru/resume/17fbe9dd0002376a820039ed1f786a5a524c79',
#  'https://hh.ru/resume/1ced62240007cf524e0039ed1f384b4e546b54',
#  'https://hh.ru/resume/9728a0e0000309d40f0039ed1f31444c325946',
#  'https://hh.ru/resume/1a68bd2e0008d8c7e30039ed1f496539364b61',
#  'https://hh.ru/resume/d99465ab0007f4276c0039ed1f384e76375a36',
#  'https://hh.ru/resume/cc11078300025f95050039ed1f506557376d65',
#  'https://hh.ru/resume/ac73947f0002b80fd50039ed1f725957516132',
#  'https://hh.ru/resume/9065a9c000091653340039ed1f4f744a6e4e54',
#  'https://hh.ru/resume/4659bb0c0008b98f4d0039ed1f43317a4f7063',
#  'https://hh.ru/resume/4e7b0794000363ce890039ed1f786b65334c75',
#  'https://hh.ru/resume/64de71c1000243142b0039ed1f326c524f6858',
#  'https://hh.ru/resume/4c67d09e00085c13280039ed1f4f4d49387359',
#  'https://hh.ru/resume/ce31cd9f0008381b780039ed1f764442503176',
#  'https://hh.ru/resume/89a08e6400072eaae00039ed1f496279575064',
#  'https://hh.ru/resume/5533eb070008bd65660039ed1f633438676274',
#  'https://hh.ru/resume/c59332ab0002b03ee10039ed1f44505761586c',
#  'https://hh.ru/resume/ce4364ab0003e5d5b30039ed1f377670457950',
#  'https://hh.ru/resume/445ff9230008c1297f0039ed1f334b5647486f',
#  'https://hh.ru/resume/4678ec15000658745b0039ed1f437678716369',
#  'https://hh.ru/resume/737e521e00040b461d0039ed1f686a4b6f7063',
#  'https://hh.ru/resume/db2389bc000787cc4f0039ed1f56314f696639',
#  'https://hh.ru/resume/e434ded2000295f3040039ed1f557076575a79',
#  'https://hh.ru/resume/8d690b9d00031aa0160039ed1f4e6a7a373255',
#  'https://hh.ru/resume/9c17a98d0008f331620039ed1f4e6450754141',
#  'https://hh.ru/resume/94cb8c02000783a1630039ed1f65776a664e31',
#  'https://hh.ru/resume/a4c438270008fe53290039ed1f763230656735',
#  'https://hh.ru/resume/dc7f2d1d0008a83b080039ed1f314669743959',
#  'https://hh.ru/resume/da3451750008ea63340039ed1f795868387a33',
#  'https://hh.ru/resume/3d2c0c57000903ad220039ed1f58304d377464',
#  'https://hh.ru/resume/1cd33ff800085944490039ed1f687076496d76',
#  'https://hh.ru/resume/1f5b1cb7000892c5480039ed1f32316c6f6479',
#  'https://hh.ru/resume/7e2d9c4a00064485ad0039ed1f467331565077',
#  'https://hh.ru/resume/fbc2cab90004f9145e0039ed1f5a4c39466b61',
#  'https://hh.ru/resume/d5f8f8c10005d764d70039ed1f4e5a4270504c',
#  'https://hh.ru/resume/388d604700087a8f8b0039ed1f7a686e647477',
#  'https://hh.ru/resume/452904660002923a610039ed1f526e784d7872',
#  'https://hh.ru/resume/0c4571c00002b572a10039ed1f37746a374267',
#  'https://hh.ru/resume/4b224b610008199b0f0039ed1f484252676e44',
#  'https://hh.ru/resume/207a1a720008be8d320039ed1f33735933494c',
#  'https://hh.ru/resume/259a0b6e000840fee80039ed1f5a76384a6178',
#  'https://hh.ru/resume/d07c4ab40001fdc3ba0039ed1f653977716436',
#  'https://hh.ru/resume/ff6e7d420007e527130039ed1f713063723546',
#  'https://hh.ru/resume/b7dd39d20007f3a7f70039ed1f307546514c39',
#  'https://hh.ru/resume/b0cedeb60008ab48cc0039ed1f794141625564',
#  'https://hh.ru/resume/7f8e2a630001ab5f410039ed1f726e506e4e57',
#  'https://hh.ru/resume/5123b15c0002e89a980039ed1f50464d567454',
#  'https://hh.ru/resume/ca6bfd6c00083ef44f0039ed1f394f6f304e79',
#  'https://hh.ru/resume/9ac07a4c0008a1eef10039ed1f6d6a66774475',
#  'https://hh.ru/resume/b787505700055f75770039ed1f64686862764c',
#  'https://hh.ru/resume/51c1f18f000918f2a60039ed1f4a77454d6735',
#  'https://hh.ru/resume/a587ecfc0007521abc0039ed1f6a574a74574e',
#  'https://hh.ru/resume/d344dbc00002f0d7d30039ed1f725254484a51',
#  'https://hh.ru/resume/ca955d5a0007b536c30039ed1f4e7947477050',
#  'https://hh.ru/resume/2ef944680000a756c30039ed1f736563726574',
#  'https://hh.ru/resume/fac94e970003d6abdb0039ed1f4d496c4e3931',
#  'https://hh.ru/resume/c05d43e900041fa17f0039ed1f7233474c5736',
#  'https://hh.ru/resume/ea8aaaf30002d4c6460039ed1f72666a704a6e',
#  'https://hh.ru/resume/f655b4a90007fb24d80039ed1f356750625064',
#  'https://hh.ru/resume/ec4dca2f000362d7550039ed1f444565527a57',
#  'https://hh.ru/resume/e5feefae000405e4fa0039ed1f477044703766',
#  'https://hh.ru/resume/6719beda0006a2b0c10039ed1f47536548367a',
#  'https://hh.ru/resume/92301e41000918a3f60039ed1f704c65595865',
#  'https://hh.ru/resume/0281b8d5000639c4b40039ed1f414336306c4c',
#  'https://hh.ru/resume/ddf9634700065b26da0039ed1f763431344d48',
#  'https://hh.ru/resume/b2fdce2800045ef5810039ed1f76505873337a',
#  'https://hh.ru/resume/d4680fd9000391e1f70039ed1f684830574d44',
#  'https://hh.ru/resume/f33fd4ab0003f6921e0039ed1f547341344430',
#  'https://hh.ru/resume/fdda295b00031a21250039ed1f5a526b687874',
#  'https://hh.ru/resume/04c336b9000400b0c40039ed1f744843773264',
#  'https://hh.ru/resume/390781e100038730f20039ed1f563276645a4f',
#  'https://hh.ru/resume/bf2479c800091dfd7c0039ed1f3543446b7973',
#  'https://hh.ru/resume/3abb5f440003fd0ef70039ed1f334f41365165',
#  'https://hh.ru/resume/05935c340005c513210039ed1f395567693872',
#  'https://hh.ru/resume/89f3dfb400029e1d790039ed1f75566d384f79',
#  'https://hh.ru/resume/b0d83207000859eef60039ed1f30667964316c',
#  'https://hh.ru/resume/d0608a890008ea719e0039ed1f714e5965634b',
#  'https://hh.ru/resume/48d331c20008a0c8990039ed1f57305a717858',
#  'https://hh.ru/resume/a4c3c1340004449f260039ed1f6a36374f434b',
#  'https://hh.ru/resume/464a78b600063b7c210039ed1f426952305552',
#  'https://hh.ru/resume/82974b240002de7da50039ed1f5158484a6634',
#  'https://hh.ru/resume/6cfd693900044942c30039ed1f526543467948',
#  'https://hh.ru/resume/8b4b0fbc0007ef7de50039ed1f43646f716e6d',
#  'https://hh.ru/resume/11c7f974000913c6ae0039ed1f68614e514345',
#  'https://hh.ru/resume/a1871af700073f6eeb0039ed1f474e7264564b',
#  'https://hh.ru/resume/ae53a1ad000270b14f0039ed1f303144414c69',
#  'https://hh.ru/resume/4f13359300028361690039ed1f387733434a59',
#  'https://hh.ru/resume/915416150008e3bc9f0039ed1f33364a31306c',
#  'https://hh.ru/resume/74a3c0320003ee0e7e0039ed1f6a6866447657',
#  'https://hh.ru/resume/5514a61100059b1fa90039ed1f6f3851593332',
#  'https://hh.ru/resume/33d602510007ab7ec70039ed1f6d62364b6d76',
#  'https://hh.ru/resume/4f0f23ad0006b6b3f50039ed1f6a6b64624148',
#  'https://hh.ru/resume/20c429ce000752a0ec0039ed1f313862466e6e',
#  'https://hh.ru/resume/e6c46c930007c03b420039ed1f743461646f6f',
#  'https://hh.ru/resume/6511677d00083fd4bf0039ed1f313636306431',
#  'https://hh.ru/resume/a98f65d80000562ef20039ed1f736563726574',
#  'https://hh.ru/resume/09e44dd90007bacfa80039ed1f7a7164434e52',
#  'https://hh.ru/resume/fa109d2f00079a22140039ed1f626f474e3941',
#  'https://hh.ru/resume/b970ecd4000165648c0039ed1f796f7272635a',
#  'https://hh.ru/resume/c6925ca400042cf3760039ed1f533352665872',
#  'https://hh.ru/resume/7e30aaab0008966fbb0039ed1f717277765377',
#  'https://hh.ru/resume/7bf076f80008b7bc8f0039ed1f703150377367',
#  'https://hh.ru/resume/aea961ec0008fc12d80039ed1f49774e536944',
#  'https://hh.ru/resume/a2f28ffc0007eab49f0039ed1f786b47464135',
#  'https://hh.ru/resume/21f16d280007191ab60039ed1f706e6a73764d',
#  'https://hh.ru/resume/fe059dcd00074ec5800039ed1f354443436a59',
#  'https://hh.ru/resume/547030940008b98a430039ed1f6c414d4d5849',
#  'https://hh.ru/resume/9f32f5d70007f6100b0039ed1f445568756132',
#  'https://hh.ru/resume/37aa6a31000817fa290039ed1f7a753457704a',
#  'https://hh.ru/resume/54760c1f00059acbbe0039ed1f7679784d6666',
#  'https://hh.ru/resume/a340afc00005c5f5200039ed1f537057674544',
#  'https://hh.ru/resume/18d3ab0e000612e0120039ed1f7477624a5476',
#  'https://hh.ru/resume/301a97c20009064fcc0039ed1f39676a69734f',
#  'https://hh.ru/resume/0651f2950004a7520d0039ed1f764e6b646a6d',
#  'https://hh.ru/resume/8ea78e660008d04f9a0039ed1f72717569717a',
#  'https://hh.ru/resume/2c6377280008b17f860039ed1f503679534b4c',
#  'https://hh.ru/resume/0a38f3ec0008c3d16f0039ed1f617433444a62',
#  'https://hh.ru/resume/f1d4b8d20008f3398c0039ed1f46647439314f',
#  'https://hh.ru/resume/32ecf9a0000505cab20039ed1f716c73524561',
#  'https://hh.ru/resume/1c1f38440008dba5760039ed1f384d5656316c',
#  'https://hh.ru/resume/d711b98c00091f1e160039ed1f6c484b65486e',
#  'https://hh.ru/resume/e28f0e360001b018ad0039ed1f544459524d4d',
#  'https://hh.ru/resume/ca90a1ce00076d330e0039ed1f39764449514d',
#  'https://hh.ru/resume/f4aebb17000770cf610039ed1f7a7972514f67',
#  'https://hh.ru/resume/5baa13c90005e3c21d0039ed1f784641717753',
#  'https://hh.ru/resume/cbdd4fbe00078f62dd0039ed1f64436c6f4146',
#  'https://hh.ru/resume/c2befb7f00074f455d0039ed1f3270614d6342',
#  'https://hh.ru/resume/9905319e000819bc0b0039ed1f7a6e38764346',
#  'https://hh.ru/resume/8be2c72a000554ba420039ed1f61396637634a',
#  'https://hh.ru/resume/e78132e30001de5de40039ed1f784c6e713972',
#  'https://hh.ru/resume/3107c1e20008811ecc0039ed1f785953475a4d',
#  'https://hh.ru/resume/ec9529ae0005bf8e460039ed1f4e6d6c327774',
#  'https://hh.ru/resume/d81cf1180006856d260039ed1f4d3268425932',
#  'https://hh.ru/resume/f65dda300000a5bf830039ed1f736563726574',
#  'https://hh.ru/resume/d567ac450003ad555d0039ed1f37517a584974',
#  'https://hh.ru/resume/b78f550d00072afced0039ed1f47437655534f',
#  'https://hh.ru/resume/ae68d8b300072a50ee0039ed1f66774f546255',
#  'https://hh.ru/resume/700a705500088f5f5a0039ed1f6372474b5333',
#  'https://hh.ru/resume/58be0018000779b7340039ed1f756f6d777a35',
#  'https://hh.ru/resume/2cbe24b3000890458b0039ed1f4a494a4b4641',
#  'https://hh.ru/resume/b1eb41c10002227b780039ed1f704455446730',
#  'https://hh.ru/resume/8277a31900092612c80039ed1f4449474e3433',
#  'https://hh.ru/resume/37a2b504000581631b0039ed1f6f4b5770374f',
#  'https://hh.ru/resume/a2065d5e0001928b550039ed1f4c365868776a',
#  'https://hh.ru/resume/54e1e62d00091ff1d50039ed1f51683164434d',
#  'https://hh.ru/resume/b13d8cdc000779a4710039ed1f38416d6c5a65',
#  'https://hh.ru/resume/2875c71e00011a18100039ed1f4c6c775a6b4a',
#  'https://hh.ru/resume/33b5e9c600034303c40039ed1f5169496b3953',
#  'https://hh.ru/resume/752bfe990008a4b8f90039ed1f566765345273',
#  'https://hh.ru/resume/195bd76a0008bb52c90039ed1f744b41306367',
#  'https://hh.ru/resume/04b4fe6b0007ee58780039ed1f794157466456',
#  'https://hh.ru/resume/8d4dbfb600091459280039ed1f38446d645272',
#  'https://hh.ru/resume/7fdb3f6100082badab0039ed1f6871506e6850',
#  'https://hh.ru/resume/054e2e11000317f8760039ed1f5a586b423563',
#  'https://hh.ru/resume/6dfd207900077cfd750039ed1f6a6943455162',
#  'https://hh.ru/resume/5e4a887400086a8cbe0039ed1f586f586d6c5a',
#  'https://hh.ru/resume/a55ae17a000727d7f10039ed1f6a625459744c',
#  'https://hh.ru/resume/70fbd20a0003b154930039ed1f41474c475663',
#  'https://hh.ru/resume/05bcda2500028027bd0039ed1f525358677361',
#  'https://hh.ru/resume/97c37be000076f60ae0039ed1f4d784f307664',
#  'https://hh.ru/resume/21c8485e000637556e0039ed1f7879366e6633',
#  'https://hh.ru/resume/ff085cc700058d09f70039ed1f6f7257564b41',
#  'https://hh.ru/resume/913c69fe0003fd49f30039ed1f456a53716c35',
#  'https://hh.ru/resume/8cc9144500085e09570039ed1f644230574a38',
#  'https://hh.ru/resume/8954a79a000694c2920039ed1f79393951516d',
#  'https://hh.ru/resume/b45940e90008ec63af0039ed1f3455536d5731',
#  'https://hh.ru/resume/5a929e7d0002ad535b0039ed1f79446b787572',
#  'https://hh.ru/resume/07c060b500076fae350039ed1f4d6335535635',
#  'https://hh.ru/resume/f36a48d80003a955960039ed1f635278697446',
#  'https://hh.ru/resume/c97eb338000720039a0039ed1f3033556d7535',
#  'https://hh.ru/resume/ada2adad0002f98aa30039ed1f6c5a4c476461',
#  'https://hh.ru/resume/3f7988ae00085929d40039ed1f777445554167',
#  'https://hh.ru/resume/31cda33f00045838890039ed1f4e3779385571',
#  'https://hh.ru/resume/773415e800009816bf0039ed1f736563726574',
#  'https://hh.ru/resume/1e544cfa0009050e0e0039ed1f456134714e77',
#  'https://hh.ru/resume/0edb2acf0007d6195d0039ed1f344c59525356',
#  'https://hh.ru/resume/34b2d4d20007a5522b0039ed1f504767366a77',
#  'https://hh.ru/resume/5b5eea600005271c800039ed1f4d50494d6b77',
#  'https://hh.ru/resume/5ab7541b0005c9bb640039ed1f383668486f4b',
#  'https://hh.ru/resume/7cbc04660001c65ce00039ed1f654174374f63',
#  'https://hh.ru/resume/c095efec0002e480420039ed1f6b4e6a595741',
#  'https://hh.ru/resume/7d1237570005906f2b0039ed1f745975493537',
#  'https://hh.ru/resume/3b3e05600007336c7f0039ed1f386e5a4e7051',
#  'https://hh.ru/resume/77fe6b690007cedbf80039ed1f7468306d6f48',
#  'https://hh.ru/resume/667b65af00044991f60039ed1f356778535055',
#  'https://hh.ru/resume/33e9a22e00085a91f20039ed1f59696f383546',
#  'https://hh.ru/resume/cc392ee70004d45c1e0039ed1f656b72615131',
#  'https://hh.ru/resume/27847f8f00040386830039ed1f7a6a4f325642',
#  'https://hh.ru/resume/393b502a0008f7022d0039ed1f483935454d5a',
#  'https://hh.ru/resume/82540e5600086109230039ed1f694947445865',
#  'https://hh.ru/resume/daed9ca100052467fb0039ed1f736c737a3161',
#  'https://hh.ru/resume/f099289e00036b253f0039ed1f5058436c7277',
#  'https://hh.ru/resume/f74bb40a0001e0e06e0039ed1f6f7a544c664d',
#  'https://hh.ru/resume/7e15af570002235f390039ed1f4b356e75684e',
#  'https://hh.ru/resume/e0aeb2ba0005080c250039ed1f65546b415362',
#  'https://hh.ru/resume/50a1dd4d0002761ece0039ed1f43766b387932',
#  'https://hh.ru/resume/9f0cac3d0003a0346e0039ed1f33417642746a',
#  'https://hh.ru/resume/7f2f5d8700051703e90039ed1f73516141724d',
#  'https://hh.ru/resume/2a8991a800058e49900039ed1f67414a75466e',
#  'https://hh.ru/resume/235344b70008fee38b0039ed1f6d62565a6d67',
#  'https://hh.ru/resume/f106930a00093253720039ed1f47424256504c',
#  'https://hh.ru/resume/92d3f17f0003f8d4010039ed1f584a4f4a786c',
#  'https://hh.ru/resume/7d58de270008f1a1ab0039ed1f315755796b68',
#  'https://hh.ru/resume/46e642cf0008fe67a50039ed1f6e4b68653979',
#  'https://hh.ru/resume/bfeb7f3d000314cb8e0039ed1f446c66664a31',
#  'https://hh.ru/resume/411ad26e000429c4720039ed1f476d784e6c6e',
#  'https://hh.ru/resume/4c70821f0002852b660039ed1f4c6f756b4772',
#  'https://hh.ru/resume/142ec9da0008a15f510039ed1f535a6c337245',
#  'https://hh.ru/resume/bc34544e0006f189020039ed1f36366f736565',
#  'https://hh.ru/resume/5df782980008368fd40039ed1f6b5472696930',
#  'https://hh.ru/resume/0d236af2000744c5780039ed1f564942764130',
#  'https://hh.ru/resume/0c677be800077679780039ed1f623050315a39',
#  'https://hh.ru/resume/fc5c60f10008fbdc020039ed1f3833644e4555',
#  'https://hh.ru/resume/86db20f500084b4fba0039ed1f4943336a6d49',
#  'https://hh.ru/resume/f543708a00089711dc0039ed1f50617465364a',
#  'https://hh.ru/resume/802989100000ec650c0039ed1f76376a543571',
#  'https://hh.ru/resume/7caab7a10001ff84ae0039ed1f3752544a5034',
#  'https://hh.ru/resume/6cbfe46b00012ee2c50039ed1f6a6d614c6b4c',
#  'https://hh.ru/resume/9b8b9a7100082e62650039ed1f4d4f53744c43',
#  'https://hh.ru/resume/d0be208400020688b10039ed1f4f7a3778304b',
#  'https://hh.ru/resume/50869bbe0003fa92a20039ed1f4634617a7875',
#  'https://hh.ru/resume/19f622e000028836ff0039ed1f49575272736f',
#  'https://hh.ru/resume/4fa944fb000599d58a0039ed1f756d44544373',
#  'https://hh.ru/resume/69fdfee5000810e0510039ed1f46796f4a4833',
#  'https://hh.ru/resume/15f506de00040904440039ed1f744d427a4146',
#  'https://hh.ru/resume/80ff8d08000327a0db0039ed1f3878476c774f',
#  'https://hh.ru/resume/69a6269600082ac6120039ed1f5536516c4851',
#  'https://hh.ru/resume/1eab54ea000414186c0039ed1f4c3135616372',
#  'https://hh.ru/resume/0745aca4000204c9270039ed1f4e5769785073',
#  'https://hh.ru/resume/30ea4cac0003588cd40039ed1f764671565256',
#  'https://hh.ru/resume/d2828b2b0004346a080039ed1f654765483752',
#  'https://hh.ru/resume/aa36322000071879390039ed1f734349557948',
#  'https://hh.ru/resume/58b82baa0004206a6c0039ed1f46566f313152',
#  'https://hh.ru/resume/8072860a00039029820039ed1f6d3054666c6c',
#  'https://hh.ru/resume/4f102a520007b277660039ed1f49754e536238',
#  'https://hh.ru/resume/d50716d400087e6eed0039ed1f544e306c5877',
#  'https://hh.ru/resume/5c08de5d00052f11d30039ed1f7a3867467834',
#  'https://hh.ru/resume/c7b2b7cb0008eac6400039ed1f54556b4c4557',
#  'https://hh.ru/resume/3b866ce60006398da00039ed1f6d6f67386244',
#  'https://hh.ru/resume/a3344d3f0008ffb5720039ed1f556f7a73784b',
#  'https://hh.ru/resume/6b7b23d80001c4b1fd0039ed1f6f6e62483245',
#  'https://hh.ru/resume/e4c72bb00008b7fd030039ed1f4a6a58674559',
#  'https://hh.ru/resume/c5087f920003809adb0039ed1f534754366742',
#  'https://hh.ru/resume/3f3831d10007bb50ec0039ed1f59566b436463',
#  'https://hh.ru/resume/4bb4b12300089069de0039ed1f48414f4d4763',
#  'https://hh.ru/resume/9ae3391100076a143d0039ed1f493051684c32',
#  'https://hh.ru/resume/645a7b99000308b34a0039ed1f734b766b6f45',
#  'https://hh.ru/resume/dd0958900008ea8cb80039ed1f4670366e6b73',
#  'https://hh.ru/resume/f67d94e500091a5d590039ed1f667a47564b59',
#  'https://hh.ru/resume/34af49380007c812100039ed1f6a6d65633874',
#  'https://hh.ru/resume/b7d7ebb20007604d720039ed1f663866455a63',
#  'https://hh.ru/resume/9cf73a230008ca704d0039ed1f416f38373351',
#  'https://hh.ru/resume/c3906b38000638863a0039ed1f7a5176576179',
#  'https://hh.ru/resume/5b582716000806a1d90039ed1f59334649544a',
#  'https://hh.ru/resume/664f6f870008ea65de0039ed1f4a5a6271466b',
#  'https://hh.ru/resume/2dc1ad3a00068e1fb00039ed1f38614f384879',
#  'https://hh.ru/resume/52c05f1c00036268f00039ed1f77745a305853',
#  'https://hh.ru/resume/5905e5fc00029a555e0039ed1f756145306f42',
#  'https://hh.ru/resume/9b25213a000592f1de0039ed1f6a6469715943',
#  'https://hh.ru/resume/9476ff5d00045873be0039ed1f5778417a4c57',
#  'https://hh.ru/resume/f612fa5400023e203c0039ed1f524d4d696c62',
#  'https://hh.ru/resume/f5d3806c000579e5c10039ed1f744564653650',
# ...
#  'https://hh.ru/resume/6ece07b30008dee4130039ed1f51475471654c',
#  'https://hh.ru/resume/87dfd3d70007ed09d00039ed1f553759594f55',
#  'https://hh.ru/resume/acf5514600021044fb0039ed1f307a36304348',
#  'https://hh.ru/resume/72923ac60008c2cbe10039ed1f4c494b37707a',
#  'https://hh.ru/resume/c8a5eaf900082271270039ed1f755566696d6d',
#  'https://hh.ru/resume/fd3a98d0000635b8500039ed1f515761474465',
#  'https://hh.ru/resume/49a34ee10008dc0b530039ed1f61627064656f',
#  'https://hh.ru/resume/fe0714d400050b2e670039ed1f323547773644',
#  'https://hh.ru/resume/7add912e00055acfd00039ed1f544d30566e45',
#  'https://hh.ru/resume/a9d000ff0008b3d64a0039ed1f65725242744f',
#  'https://hh.ru/resume/e4fb581f00079315e70039ed1f686d4e6d4a6e',
#  'https://hh.ru/resume/b0bdda4d000315fdc90039ed1f4a3935354451',
#  'https://hh.ru/resume/004cab0d00032986ae0039ed1f75333667346e',
#  'https://hh.ru/resume/42c008a900029d198e0039ed1f4e4378306f4e',
#  'https://hh.ru/resume/5e1b970600026399000039ed1f705631513264',
#  'https://hh.ru/resume/9f78eee700019994930039ed1f587675425934',
#  'https://hh.ru/resume/d5d97ef400075995ee0039ed1f746f736e4b4f',
#  'https://hh.ru/resume/450483e6000877a2c30039ed1f674d4f514544',
#  'https://hh.ru/resume/2e0098c60002dabfbd0039ed1f63374d307174',
#  'https://hh.ru/resume/3a6ddf8700071390e30039ed1f464c31574c34',
#  'https://hh.ru/resume/6d3562d6000719f27c0039ed1f705a584c4648',
#  'https://hh.ru/resume/b17f2c270007ae76340039ed1f434634475778',
#  'https://hh.ru/resume/eb55ebc50003af7ac80039ed1f4d4174505356',
#  'https://hh.ru/resume/88a6e2e70007c5c40a0039ed1f4576767a7275',
#  'https://hh.ru/resume/280a7f8500034415930039ed1f72796e55344d',
#  'https://hh.ru/resume/afe00fe600077397c60039ed1f6c6f6f506a67',
#  'https://hh.ru/resume/debb6535000588bef10039ed1f5a536b6b7930',
#  'https://hh.ru/resume/52b4322500060867470039ed1f546e62557a62',
#  'https://hh.ru/resume/cff0c7840008df66c40039ed1f4f494c74544a',
#  'https://hh.ru/resume/4f186b2f0002d557010039ed1f5635374a4d43',
#  'https://hh.ru/resume/c27dd09a00063a74280039ed1f6c6863684d59',
#  'https://hh.ru/resume/59bb151a000259d19b0039ed1f757658334978',
#  'https://hh.ru/resume/e56465b90008b895b50039ed1f546d55615437',
#  'https://hh.ru/resume/d753ce9100071c62d70039ed1f394277573749',
#  'https://hh.ru/resume/b9fa3bdb0002dbd6d70039ed1f4839496d3279',
#  'https://hh.ru/resume/8ede90470005d4825c0039ed1f6d3457484e66',
#  'https://hh.ru/resume/d83379fb000485e8ea0039ed1f42694547335a',
#  'https://hh.ru/resume/9ccb493700021fdd2a0039ed1f64544846396a',
#  'https://hh.ru/resume/75166c2d00034b614e0039ed1f543970486278',
#  'https://hh.ru/resume/0ecb7fa70001f4fdcf0039ed1f52334b476444',
#  'https://hh.ru/resume/ec0d85650008885b8f0039ed1f784a526e3564',
#  'https://hh.ru/resume/ef52e72c00077c90e80039ed1f564b4e44586e',
#  'https://hh.ru/resume/b653775f00019ebca90039ed1f4b5a48353977',
#  'https://hh.ru/resume/419d9ba800021347630039ed1f574878596573',
#  'https://hh.ru/resume/064277cd00071a648b0039ed1f42484e484a6c',
#  'https://hh.ru/resume/e1cee76c00081f1e7c0039ed1f384858486638',
#  'https://hh.ru/resume/c829fa2200081212910039ed1f4d44676f7974',
#  'https://hh.ru/resume/acf10b9b0002917eca0039ed1f3039777a334b',
#  'https://hh.ru/resume/1e1949d00008f90ca50039ed1f6b544774524c',
#  'https://hh.ru/resume/06d7616a00089457b20039ed1f765139386d6f',
#  'https://hh.ru/resume/3a9952e200090d6bb50039ed1f68566b416232',
#  'https://hh.ru/resume/90e6f41e00037ab05e0039ed1f59486a665843',
#  'https://hh.ru/resume/c61c021c0004d7129a0039ed1f76493776686d',
#  'https://hh.ru/resume/4e3283b80002ed59ea0039ed1f737473547159',
#  'https://hh.ru/resume/2e634fd30008a35aaa0039ed1f455467547344',
#  'https://hh.ru/resume/85614abf0005a9fd4f0039ed1f4761644a476f',
#  'https://hh.ru/resume/7fd6b4fc0002f6f0760039ed1f537565315261',
#  'https://hh.ru/resume/f7693c130007c5ce070039ed1f57417055536e',
#  'https://hh.ru/resume/90eb06ba000511871f0039ed1f516577346b50',
#  'https://hh.ru/resume/4c946d2e0008ebb4cd0039ed1f6a7a43314666',
#  'https://hh.ru/resume/38a896470007b8420a0039ed1f315744485079',
#  'https://hh.ru/resume/81337eed000853814b0039ed1f514c37395934',
#  'https://hh.ru/resume/3aecd0bd000286bac30039ed1f666e4e793946',
#  'https://hh.ru/resume/d34f20ae0008e49fea0039ed1f384341656267',
#  'https://hh.ru/resume/16c1d2890003cf1d230039ed1f375a6f746f71',
#  'https://hh.ru/resume/aea539220007b526830039ed1f6a3158456958',
#  'https://hh.ru/resume/6fe8e76b0003f1d60d0039ed1f6c474b484c68',
#  'https://hh.ru/resume/cd3ddf380008144ded0039ed1f334b36694966',
#  'https://hh.ru/resume/f5ba9fcc0007ecf62c0039ed1f6e6b414b7851',
#  'https://hh.ru/resume/a487ccb800031c8cec0039ed1f556d416d4757',
#  'https://hh.ru/resume/b2ef89af000870376e0039ed1f6c333735344f',
#  'https://hh.ru/resume/315b10af0007a225560039ed1f58636a723644',
#  'https://hh.ru/resume/2ebff1950000bda5540039ed1f736563726574',
#  'https://hh.ru/resume/9079db27000140969b0039ed1f4e675a57476a',
#  'https://hh.ru/resume/f21c59470004152c750039ed1f786f32494c50',
#  'https://hh.ru/resume/cb79b271000834a9ad0039ed1f346242656663',
#  'https://hh.ru/resume/e315ced800042c73720039ed1f6d4e416d4a52',
#  'https://hh.ru/resume/4c900ee00000416ecd0039ed1f736563726574',
#  'https://hh.ru/resume/02ea03f900093098a10039ed1f71576b326439',
#  'https://hh.ru/resume/0406e0e10008643bea0039ed1f357863575759',
#  'https://hh.ru/resume/c4d91f200005c682d80039ed1f41414e745331',
#  'https://hh.ru/resume/b2dc471e00079c9a3e0039ed1f6d3443327247',
#  'https://hh.ru/resume/0606176c0006e4959f0039ed1f6d6b45557935',
#  'https://hh.ru/resume/3ccea79700086dbf400039ed1f304255646174',
#  'https://hh.ru/resume/a340842d00085009e50039ed1f383662435378',
#  'https://hh.ru/resume/ef10973c0007f6a2bc0039ed1f5535744e5271',
#  'https://hh.ru/resume/7f97b0ff0003f11cb40039ed1f5734644e5531',
#  'https://hh.ru/resume/608145fd00044639680039ed1f37784a7a4278',
#  'https://hh.ru/resume/719a7e0900018172ed0039ed1f59325232376a',
#  'https://hh.ru/resume/c7625b5b0005574b850039ed1f6d6733686e4b',
#  'https://hh.ru/resume/1661b2a50005b81d310039ed1f62797069726d',
#  'https://hh.ru/resume/47ca22ef0009196ef90039ed1f4646356e3457',
#  'https://hh.ru/resume/b632efa40005e311770039ed1f6f6e56685968',
#  'https://hh.ru/resume/bc5781e000040d15990039ed1f774c65557466',
#  'https://hh.ru/resume/b8159864000799a6000039ed1f587a55314769',
#  'https://hh.ru/resume/dbb57b4700064516860039ed1f38336679656f',
#  'https://hh.ru/resume/16ae2ada00086c7b220039ed1f6462734e5066',
#  'https://hh.ru/resume/698b17460008b7a8df0039ed1f706f38443430',
#  'https://hh.ru/resume/a592e78a00044e49810039ed1f32414e327a73',
#  'https://hh.ru/resume/c08cc9d6000867f27a0039ed1f726550494169',
#  'https://hh.ru/resume/891f6df70006d6f8110039ed1f786654474e45',
#  'https://hh.ru/resume/cd06223900092f8afe0039ed1f59516144727a',
#  'https://hh.ru/resume/194b29db0008e8a44f0039ed1f354d58483269',
#  'https://hh.ru/resume/465f30dc000742f49a0039ed1f4a4e73593746',
#  'https://hh.ru/resume/dd13a21b000324c3ca0039ed1f786370485950',
#  'https://hh.ru/resume/aae4486c0005dd79ba0039ed1f6873506d5931',
#  'https://hh.ru/resume/9adac01a000586032a0039ed1f47676f797156',
#  'https://hh.ru/resume/32d14b5b000344bfcb0039ed1f4e305044756e',
#  'https://hh.ru/resume/d26d7b47000811f4680039ed1f535765643555',
#  'https://hh.ru/resume/469d3c2a0008dc37a00039ed1f59475a417032',
#  'https://hh.ru/resume/c727eaa8000785b4d50039ed1f33306d614341',
#  'https://hh.ru/resume/b497be1a0003fd44ae0039ed1f32594f695254',
#  'https://hh.ru/resume/fcb0d2e10005b27b6d0039ed1f6d773572484d',
#  'https://hh.ru/resume/e84ca30e00084784540039ed1f365342635a48',
#  'https://hh.ru/resume/9b2139790005a40ed30039ed1f656469703548',
#  'https://hh.ru/resume/f779db5e0007e90ea70039ed1f6d3272616e47',
#  'https://hh.ru/resume/0dcbb0fa000785b9860039ed1f664966314337',
#  'https://hh.ru/resume/38882a920003bf1d650039ed1f68575a474934',
#  'https://hh.ru/resume/7f8464b50008e010420039ed1f4133314b4333',
#  'https://hh.ru/resume/4c034d2d0008c847a90039ed1f5a746a303264',
#  'https://hh.ru/resume/f53f737100042d8b450039ed1f474256456f75',
#  'https://hh.ru/resume/5dc5d3e500030393a80039ed1f567a50667642',
#  'https://hh.ru/resume/7650dea300072188ce0039ed1f54735762566b',
#  'https://hh.ru/resume/30484ff50008d22b470039ed1f6e514e486463',
#  'https://hh.ru/resume/c0216b220007287fca0039ed1f597a706e7837',
#  'https://hh.ru/resume/291e450900032d0f7d0039ed1f526770755437',
#  'https://hh.ru/resume/d2c8419800058c88710039ed1f6f74766e4a49',
#  'https://hh.ru/resume/a1088ea10001298d230039ed1f494134676370',
#  'https://hh.ru/resume/75e2d37100028588900039ed1f714e6c645558',
#  'https://hh.ru/resume/ac75224c0004419e8e0039ed1f76786c503938',
#  'https://hh.ru/resume/f7cbe139000587a8220039ed1f697534435730',
#  'https://hh.ru/resume/778a09f8000898d9980039ed1f4d4d7647355a',
#  'https://hh.ru/resume/3720922b0002b39de00039ed1f575847324132',
#  'https://hh.ru/resume/cba53a270003aa475f0039ed1f63763564566f',
#  'https://hh.ru/resume/0b42fa130003cfafde0039ed1f415678635455',
#  'https://hh.ru/resume/263301dd0003f5567e0039ed1f6f394b4c5534',
#  'https://hh.ru/resume/008ff24f00090f21e60039ed1f635250765056',
#  'https://hh.ru/resume/1226402c00030cec980039ed1f6b7968674662',
#  'https://hh.ru/resume/6e64aad4000721d5f30039ed1f35536c545539',
#  'https://hh.ru/resume/3262041d0000a6199c0039ed1f736563726574',
#  'https://hh.ru/resume/a98bc1110003c7da3a0039ed1f5a756241496f',
#  'https://hh.ru/resume/cc9c52f700041c77eb0039ed1f68425a45516c',
#  'https://hh.ru/resume/28a989300004fb756a0039ed1f4e6567554e79',
#  'https://hh.ru/resume/4951a2d70002f111150039ed1f6f6a4d526e5a',
#  'https://hh.ru/resume/d1b1c1f20008d1bf740039ed1f377235397a68',
#  'https://hh.ru/resume/cc87c3a300021276480039ed1f315147373550',
#  'https://hh.ru/resume/8e91f14200024d54ea0039ed1f63636a657453',
#  'https://hh.ru/resume/5d72d6a000031528850039ed1f7a71556a487a',
#  'https://hh.ru/resume/6fec3d070003d0d4e90039ed1f6a4c496d7837',
#  'https://hh.ru/resume/d520524600042db3b80039ed1f43755a656d5a',
#  'https://hh.ru/resume/5b10492300067009f70039ed1f3569716c776a',
#  'https://hh.ru/resume/b24bd134000806f8e30039ed1f6645714b6836',
#  'https://hh.ru/resume/e5326550000927677a0039ed1f4a427a746656',
#  'https://hh.ru/resume/7ff989e00008483e010039ed1f734873787833',
#  'https://hh.ru/resume/be87434400027c702d0039ed1f5264724b6778',
#  'https://hh.ru/resume/691e1f380008c20c8e0039ed1f4c3579576557',
#  'https://hh.ru/resume/ffb0867800090603020039ed1f33497654616c',
#  'https://hh.ru/resume/21dfe74b0004511f190039ed1f594a34797654',
#  'https://hh.ru/resume/02dfdd810008da90e90039ed1f796955437764',
#  'https://hh.ru/resume/75903f6b00065a70860039ed1f4d4d476b534a',
#  'https://hh.ru/resume/7a2fc8a40003acec9f0039ed1f32454b557432',
#  'https://hh.ru/resume/2dd551020005db53040039ed1f37474d76305a',
#  'https://hh.ru/resume/d5ec092c0007ab4a080039ed1f396759435675',
#  'https://hh.ru/resume/556b61830000b21cac0039ed1f736563726574',
#  'https://hh.ru/resume/a6346ec000033644ba0039ed1f493069313130',
#  'https://hh.ru/resume/f17cacb10008e48c020039ed1f396f7252786a',
#  'https://hh.ru/resume/925a9086000722d9610039ed1f776b594a4730',
#  'https://hh.ru/resume/26d2ca370005c68d500039ed1f754d69654a53',
#  'https://hh.ru/resume/0b5b9f320001f969650039ed1f79516c566f67',
#  'https://hh.ru/resume/18fe66580007eea46c0039ed1f4b7170506833',
#  'https://hh.ru/resume/4b992e5d000355fbda0039ed1f506278483562',
#  'https://hh.ru/resume/79a84a380005a592490039ed1f4f6f34704e49',
#  'https://hh.ru/resume/48b7d7da0008b847c30039ed1f784469705749',
#  'https://hh.ru/resume/ac043a1b00086260b90039ed1f734e47594865',
#  'https://hh.ru/resume/dd2454ee0003c0cbad0039ed1f515a4c69736c',
#  'https://hh.ru/resume/cc54ad21000530e6250039ed1f69616d617345',
#  'https://hh.ru/resume/f33e4b520001a577ad0039ed1f684a44644d63',
#  'https://hh.ru/resume/6815fe07000614262a0039ed1f7363517a5a54',
#  'https://hh.ru/resume/6631f5c800031bc78d0039ed1f535242524467',
#  'https://hh.ru/resume/b0b714f00007f5eeb30039ed1f456672514761',
#  'https://hh.ru/resume/1ea3c8a90008192e8b0039ed1f684948364145',
#  'https://hh.ru/resume/0d10940e0005b087730039ed1f653277665377',
#  'https://hh.ru/resume/f03e3d480004542f5a0039ed1f565a3130756c',
#  'https://hh.ru/resume/8487d3f60007f0ac8c0039ed1f516a35616270',
#  'https://hh.ru/resume/6ea5cfe50008193fc40039ed1f427a3065414e',
#  'https://hh.ru/resume/46eca5420008e01ba50039ed1f48534476544a',
#  'https://hh.ru/resume/4113bfdb000871cd420039ed1f637570467234',
#  'https://hh.ru/resume/d5c93770000430eb040039ed1f664756355a67',
#  'https://hh.ru/resume/372557090007b3b45a0039ed1f367a4171544b',
#  'https://hh.ru/resume/57144e170008ebcaa70039ed1f446b6d386572',
#  'https://hh.ru/resume/1f9ecde900077184b10039ed1f57586456746d',
#  'https://hh.ru/resume/8cdceb660000a13be90039ed1f736563726574',
#  'https://hh.ru/resume/02c532310001b80a7f0039ed1f794564496756',
#  'https://hh.ru/resume/fc2301f10002e877960039ed1f483631785370',
#  'https://hh.ru/resume/de58172b00074d62030039ed1f566d6a344a41',
#  'https://hh.ru/resume/b097b4f700058b93390039ed1f453268764833',
#  'https://hh.ru/resume/e2505cde0008315b830039ed1f6447486b5a5a',
#  'https://hh.ru/resume/20fac4a30007f5f6870039ed1f755551783570',
#  'https://hh.ru/resume/d95871db00042e30be0039ed1f773976373051',
#  'https://hh.ru/resume/7a7326e700058b1a150039ed1f6136396c4847',
#  'https://hh.ru/resume/8c3b8ad30008cce9960039ed1f7a37576b304c',
#  'https://hh.ru/resume/6f67e0430001c013ac0039ed1f54487a563258',
#  'https://hh.ru/resume/cc5c1cf100075c0a850039ed1f33674d526e62',
#  'https://hh.ru/resume/34cd682d0008d5d1850039ed1f6b6f43385547',
#  'https://hh.ru/resume/534a3712000499fbd90039ed1f6c58727a4f30',
#  'https://hh.ru/resume/fe7ae51f000257ed130039ed1f355a72334a53',
#  'https://hh.ru/resume/134b61550002f6548b0039ed1f455539756756',
#  'https://hh.ru/resume/115ecb0500020328700039ed1f37636d585067',
#  'https://hh.ru/resume/ebb7a11a00043a9dc60039ed1f69745a616858',
#  'https://hh.ru/resume/eb64c88600033ec9c90039ed1f684f47614959',
#  'https://hh.ru/resume/73bb1e9600078bc20a0039ed1f635633776441',
#  'https://hh.ru/resume/781a473000085563090039ed1f347274507251',
#  'https://hh.ru/resume/7078ed5b0005b91ac70039ed1f6a554c6d7035',
#  'https://hh.ru/resume/5f457ed00007d696140039ed1f615a79536447',
#  'https://hh.ru/resume/88f641870000dd94220039ed1f385158363879',
#  'https://hh.ru/resume/80d6a2ce00081a8ec50039ed1f41736f796a33',
#  'https://hh.ru/resume/7d3dd8fd0008ceb1190039ed1f61724f46496b',
#  'https://hh.ru/resume/b4dbb5a00007d2bb810039ed1f5a5573327963',
#  'https://hh.ru/resume/cd2d424400059ef9f40039ed1f506b6341634f',
#  'https://hh.ru/resume/fbfb3fae00026c43ba0039ed1f45733450536d',
#  'https://hh.ru/resume/7bd6cd4b0005e33ab80039ed1f5a6e58774170',
#  'https://hh.ru/resume/2c0ff1190003999b6a0039ed1f336a7842724e',
#  'https://hh.ru/resume/b399f0440001cbb1ce0039ed1f316b49664267',
#  'https://hh.ru/resume/90fbd3cb0003f6e6db0039ed1f387478736d45',
#  'https://hh.ru/resume/5aaaade10007f040bd0039ed1f426f79377479',
#  'https://hh.ru/resume/3434b2dd00032f88270039ed1f33474f52426a',
#  'https://hh.ru/resume/0fe03f5a0005bb13080039ed1f6e5375506e6f',
#  'https://hh.ru/resume/85e9e7e300069f77d40039ed1f6d5238374b4a',
#  'https://hh.ru/resume/7a0154ec0007c6aa370039ed1f6e474c525147',
#  'https://hh.ru/resume/85a365b30008a940030039ed1f4a5653427371',
#  'https://hh.ru/resume/c224a8860008686bff0039ed1f7354594e5543',
#  'https://hh.ru/resume/8eec3cad0007e8cd850039ed1f6857364d6a42',
#  'https://hh.ru/resume/6fe8f34800071362a90039ed1f356833347245',
#  'https://hh.ru/resume/95b959b70008fcd5000039ed1f44534a44644a',
#  'https://hh.ru/resume/9af36069000154c60b0039ed1f6b35564a797a',
#  'https://hh.ru/resume/a35dd899000303d2a10039ed1f4f4d34567730',
#  'https://hh.ru/resume/de2788d00007f0b0380039ed1f54326253774c',
#  'https://hh.ru/resume/ed93e5030007d816010039ed1f524674754a72',
#  'https://hh.ru/resume/46119af60008ddc3c10039ed1f6c697a574256',
#  'https://hh.ru/resume/17ba247f0008422ebb0039ed1f58734e514c4a',
#  'https://hh.ru/resume/433ca82c000754ceeb0039ed1f685139596830',
#  'https://hh.ru/resume/48fc400a00092f554d0039ed1f4e6a30705037',
#  'https://hh.ru/resume/d21a15b90007861b930039ed1f4179317a3330',
#  'https://hh.ru/resume/4420358c0003c3c2060039ed1f55365574326d',
#  'https://hh.ru/resume/7ddf021a00084dace70039ed1f423258786e67',
#  'https://hh.ru/resume/7017194800072e3eb40039ed1f6c453158705a',
#  'https://hh.ru/resume/a867514d0004f3bbd40039ed1f50304a696474',
#  'https://hh.ru/resume/83ec15ff00030c55ce0039ed1f55715043746d',
#  'https://hh.ru/resume/fdee6f400001ecb2d20039ed1f476362767661',
#  ...]

# %% [markdown]
# ### Парсинг информации из каждого резюме

# %%
# Переходим по любой ссылке в резюме, с указанной зарплатой
# Смотрим код и копируем class заголовка (для этого нажмем "проверить" и выделим заголовок, т.е. название позиции, например Python developer)
# Аналогично скопируем class зарплаты
# Также ищем class ключевых навыков

# %%
# Функция для получения данных резюме
def get_resume(link):

  # Делаем запрос к переданной ссылке
  data = requests.get(
      url = link,
      headers={"user-agent":ua.random}
  )
  if data.status_code != 200:
    return

  soup = BeautifulSoup(data.content, "lxml")

  # Вытащим из ссылки id резюме
  id_link = link.split("/")[-1]

  # Спарсим пол (мужчина / женщина)
  try:
    gender = soup.find("span", attrs={"data-qa": "resume-personal-gender"}).text.replace("\u2009","").replace("\xa0", " ")
  except:
    gender = ""

  # Спарсим возраст
  try:
    age = soup.find("span", attrs={"data-qa": "resume-personal-age"}).text.replace("\u2009","").replace("\xa0", " ")
  except:
    age = ""

  # Спарсим дату рождения
  try:
    date_of_birth = soup.find("span", attrs={"data-qa":"resume-personal-birthday"}).text.replace("\xa0", " ")
  except:
    date_of_birth = ""

  # Спарсим статус поиска работы (Активно ищет работу / Не ищет работу / Рассматривает предложения / и т.д.)
  try:
    job_search_status = soup.find("span", attrs={"data-qa": "job-search-status"}).text
  except:
    job_search_status = ""

    # Спарсим информацию "О себе"
  try:
    about_me = soup.find("div", attrs={"data-qa": "resume-block-skills-content"}).text.strip()
  except:
    about_me = ""

    # Спарсим информацию об образовании
  try:
    # Находим блок образования и извлекаем из него текст
    education_blocks = soup.find_all("div", attrs={"data-qa": "resume-block-education"})
    education = []
    for block in education_blocks:
      education_info = block.text.strip().replace("\n", " ").replace("\xa0", " ")
      education.append(education_info)
  except:
    education = []

    # Спарсим информацию о языках
  try:
     language_blocks = soup.find_all("div", attrs={"data-qa": "resume-block-language-item"})
     language = []
     for block in language_blocks:
         lang_info = block.text.strip().replace("\n", " ").replace("\xa0", " ")
         language.append(lang_info)
  except:
          language = []


  # Спарсим город проживания
  try:
    city_of_residence = soup.find("span", attrs={"data-qa":"resume-personal-address"}).text.replace("\xa0", " ")
  except:
    city_of_residence = ""

  # Спарсим готовность к переезду, командировкам
  try:
    # Находим весь текст в блоке "Готовность к переезду/командировкам"
    movings = soup.find(attrs={"class":"bloko-translate-guard"}).text.replace("\xa0", " ")
    # Разделяем текст на части по запятой
    parts = movings.split(',')
    # Соединяем части, от второй до предпоследней, с запятой-разделителем
    # Первая часть не нужна - это город проживания; последняя - это готовность к командировкам
    # Между первой и последней частями - это готовность к переезду
    # Здесь может быть как одна часть (готов к переезду)
    # Также может быть несколько частей, например готов к переезду (Москва, Россия)
    # В этом примере запятая стоит между "Москва" и "Россия", которая делит нужную фразу на несколько частей
    # Поэтому и собираем несколько частей в одну
    # Получаем готовность к переезду
    moving = ','.join(part for part in parts[1:-1]).strip()
    # Берем последнюю часть, получаем готовность к командировкам
    business_trip = parts[-1].strip()
  except:
    moving = ""
    business_trip = ""

  # Спарсим название позиции
  try:
    name = soup.find(attrs={"class":"resume-block__title-text"}).text
  except:
    name = ""

  # Спарсим зарплату и уберем лишние символы (\u2009, \xa0)
  try:
    salary = soup.find(attrs={"class":"resume-block__salary"}).text.replace("\u2009","").replace("\xa0", " ")
  except:
    salary = ""

  # Спарсим специализации и график работы
  try:
    # Находим все блоки с class "resume-block-container"
    specialized_blocks = soup.find_all(attrs={"class":"resume-block-container"})
    # Проверим каждый блок и найдем блок в котором есть class "resume-block__specialization"
    for block in specialized_blocks:
      if block.find(attrs={"class":"resume-block__specialization"}):
        # Запишем в переменную текст найденного блока
        # Предварительно добавив пробелы перед заглавными буквами и затем удалив лишние пробелы (в начале)
        specialization_schedule = re.sub(r'([А-ЯA-Z])', r' \1', block.text).strip()
  except:
    specialization_schedule = ""

  # Спарсим общее время опыта работы
  try:
    experience_all_period = soup.find(attrs={"class":"resume-block__title-text resume-block__title-text_sub"}).text.replace("\xa0", " ")
  except:
    experience_all_period = ""

  # Спарсим опыт работы
  try:
    # Найдем все блоки с class="resume-block-item-gap" в блоке с "data-qa":"resume-block-experience"
    # В самом первом блоке информация дублируется, поэтому список создадим без самого первого элемента
    blocks_item_gap = soup.find(attrs={"data-qa":"resume-block-experience"}).find_all(attrs={"class":"resume-block-item-gap"})[1:]
    # Создадим паттерн для последующего поиска блоков
    reexp = re.compile('bloko-column.*')
    blocks_all = [] # Сюда будем складывать найденные блоки
    experience = [] # Сюда будем складывать итоговый текст
    # Проходимся по каждому вышенайденному блоку и находим все блоки с атрибутом class по заданному паттерну
    for block_item in blocks_item_gap:
      blocks_all.append (block_item.find_all(class_=reexp)[1:]) # Аналогично нам нужен список без самого первого элемента
    # Проходимся по каждому списку блоков в общем списке blocks_all
    for block in blocks_all:
      # Проходимся по каждому элементу
      for data in block:
        # print(data.text.replace("\xa0", " "))
        # Полученный текст из каждого элемента складываем в итоговый список
        experience.append(data.text.replace("\xa0", " "))
  except:
    experience = ""

  # Спарсим ключевые навыки
  # Находим атрибут, где находятся все ключевые навыки (data-qa = "skills-table); далее находим class для каждого отдельного навыка, оставляем class с text
  try:
    tags = [tag.text for tag in soup.find(attrs={"data-qa":"skills-table"}).find_all(attrs={"class":"bloko-tag__section_text"})]
  except:
    tags = []


  # Собираем все найденные атрибуты в словарь, в конце словаря добавляем url-адрес резюме
  resume = {
      "id":id_link,
      "gender":gender,
      "age":age,
      "date_of_birth":date_of_birth,

      "about_me": about_me,
      "education": education,
      "language": language,

      "job_search_status":job_search_status,
      "city_of_residence":city_of_residence,
      "moving":moving,
      "business_trip":business_trip,
      "name":name,
      "salary":salary,
      "specialization_schedule":specialization_schedule,
      "experience_all_period":experience_all_period,
      "experience":experience,
      "tags":tags,
      "link":link
  }
  return resume

# %%
# Проверяем работу на первых 2 ссылках
for a in link_resume[:2]:
  print(get_resume(a))
  time.sleep(1)
# Out:
# {'id': '564d2d4d00090608d70039ed1f497074436c4e', 'gender': 'Мужчина', 'age': '35 лет', 'date_of_birth': '15 марта 1989', 'about_me': '', 'education': ['ОбразованиеСреднее образование'], 'language': [], 'job_search_status': 'Не\xa0ищет работу', 'city_of_residence': 'Новосибирск', 'moving': 'готов к переезду (Россия, Другие регионы)', 'business_trip': 'готов к командировкам', 'name': 'Python junior developer', 'salary': '', 'specialization_schedule': 'Специализации: Программист, разработчик Занятость: полная занятость, частичная занятость, проектная работа, стажировка График работы: полный день, сменный график, гибкий график, удаленная работа, вахтовый метод', 'experience_all_period': 'Опыт работы 2 года 7 месяцев', 'experience': ['Ноябрь 2021 — по настоящее время2 года 7 месяцев', 'Самостоятельное обучениеPython developerPython\npostgreSQL\nС\\СPP\n\nGit\ndocker\nLinux'], 'tags': ['Амбициозность', 'Python', 'PostgreSQL', 'Git', 'docker', 'C', 'C++', 'Bash', 'Linux'], 'link': 'https://hh.ru/resume/564d2d4d00090608d70039ed1f497074436c4e'}
# {'id': '0de1b45d0008b61e070039ed1f6d6f4e4e4b43', 'gender': 'Мужчина', 'age': '21 год', 'date_of_birth': '13 сентября 2002', 'about_me': 'Имею опыт разработки в различных сферах на Python, знаком с различными СУБД. Мне интересны все возможные направления, где этот язык может применяться, в частности веб. Открыт к изучению новых технологий и решению сложных проблем. Я ищу должность бэкенд-разработчика (Django/FastAPI/DRF) или разработчик ботов (aiogram) на Python.\n\nЗнание основных алгоритмов и структур данных, паттернов проектирования.\n\nSoft skills: Умение работать в коллективе и в команде, аналитический склад ума, ответственность, стремление к самосовершенствованию, усидчивость.\n\nGithub: https://github.com/sgrigerc\ntg: @harcy', 'education': ['Высшее образование2025Российский университет транспорта, МоскваИТТСУ, Инженер электропоезда'], 'language': [], 'job_search_status': 'Не\xa0ищет работу', 'city_of_residence': 'Москва', 'moving': 'м. ВДНХ, не готов к переезду', 'business_trip': 'не готов к командировкам', 'name': 'Python-разработчик', 'salary': '', 'specialization_schedule': 'Специализации: Программист, разработчик Занятость: полная занятость, частичная занятость, проектная работа, волонтерство, стажировка График работы: полный день, сменный график, гибкий график, удаленная работа', 'experience_all_period': 'Опыт работы 2 года 4 месяца', 'experience': ['Ноябрь 2021 — Февраль 20242 года 4 месяца', 'Всм-СервисМоскваПрограммист PythonBackend \nСтек технологий: Python, Django, Docker, PostgreSQL, Celery. \nФункционал:\n- разработка backend части сайта;\n- разработка сайта с подключённым телеграмм ботом (aiogram).\n- исправление различных багов в проекте.'], 'tags': ['Python', 'ООП', 'Git', 'PostgreSQL', 'SQL', 'Django Framework', 'Django', 'HTML', 'CSS', 'Bootstrap', 'Stripe', 'Docker', 'Jupiter', 'SQLite', 'Умение работать в команде', 'Паттерны проектирования', 'Английский язык', 'Умение разбираться в чужом коде', 'Linux', 'Базы данных'], 'link': 'https://hh.ru/resume/0de1b45d0008b61e070039ed1f6d6f4e4e4b43'}

# %% [markdown]
# ### Парсинг и запись результата в csv файл

# %%
# Функция парсинга резюме по ссылкам и записи результатов в файл
def result_resumes(link_resume: list):
  '''
  :link_resume: список ссылок резюме
  '''

  # Создаем файл csv для записи результатов
  with open(
      '/content/drive/MyDrive/Practice2/result_resumes.csv',
      'w', newline='', encoding='utf-8') as res_file:
      # Названия столбцов
      fieldnames = ['id', 'gender', 'age',"about_me", "education", "language", 'date_of_birth', 'job_search_status',
                    'city_of_residence', 'moving', 'business_trip', 'name',
                    'salary', 'specialization_schedule',
                    'experience_all_period', 'experience', 'tags', 'link']
      writer = csv.DictWriter(res_file, fieldnames=fieldnames)
      # Записываем заголовки столбцов
      writer.writeheader()

      for link in link_resume:
        resume_data = get_resume(link)
        if resume_data: # При успешном парсинге резюме
          writer.writerow(resume_data)  # Записываем данные в CSV
        print(resume_data)
        time.sleep(1)

# %%
result_resumes(link_resume[:10])
# Out:
# {'id': '564d2d4d00090608d70039ed1f497074436c4e', 'gender': 'Мужчина', 'age': '35 лет', 'date_of_birth': '15 марта 1989', 'about_me': '', 'education': ['ОбразованиеСреднее образование'], 'language': [], 'job_search_status': 'Не\xa0ищет работу', 'city_of_residence': 'Новосибирск', 'moving': 'готов к переезду (Россия, Другие регионы)', 'business_trip': 'готов к командировкам', 'name': 'Python junior developer', 'salary': '', 'specialization_schedule': 'Специализации: Программист, разработчик Занятость: полная занятость, частичная занятость, проектная работа, стажировка График работы: полный день, сменный график, гибкий график, удаленная работа, вахтовый метод', 'experience_all_period': 'Опыт работы 2 года 7 месяцев', 'experience': ['Ноябрь 2021 — по настоящее время2 года 7 месяцев', 'Самостоятельное обучениеPython developerPython\npostgreSQL\nС\\СPP\n\nGit\ndocker\nLinux'], 'tags': ['Амбициозность', 'Python', 'PostgreSQL', 'Git', 'docker', 'C', 'C++', 'Bash', 'Linux'], 'link': 'https://hh.ru/resume/564d2d4d00090608d70039ed1f497074436c4e'}
# {'id': '0de1b45d0008b61e070039ed1f6d6f4e4e4b43', 'gender': 'Мужчина', 'age': '21 год', 'date_of_birth': '13 сентября 2002', 'about_me': 'Имею опыт разработки в различных сферах на Python, знаком с различными СУБД. Мне интересны все возможные направления, где этот язык может применяться, в частности веб. Открыт к изучению новых технологий и решению сложных проблем. Я ищу должность бэкенд-разработчика (Django/FastAPI/DRF) или разработчик ботов (aiogram) на Python.\n\nЗнание основных алгоритмов и структур данных, паттернов проектирования.\n\nSoft skills: Умение работать в коллективе и в команде, аналитический склад ума, ответственность, стремление к самосовершенствованию, усидчивость.\n\nGithub: https://github.com/sgrigerc\ntg: @harcy', 'education': ['Высшее образование2025Российский университет транспорта, МоскваИТТСУ, Инженер электропоезда'], 'language': [], 'job_search_status': 'Не\xa0ищет работу', 'city_of_residence': 'Москва', 'moving': 'м. ВДНХ, не готов к переезду', 'business_trip': 'не готов к командировкам', 'name': 'Python-разработчик', 'salary': '', 'specialization_schedule': 'Специализации: Программист, разработчик Занятость: полная занятость, частичная занятость, проектная работа, волонтерство, стажировка График работы: полный день, сменный график, гибкий график, удаленная работа', 'experience_all_period': 'Опыт работы 2 года 4 месяца', 'experience': ['Ноябрь 2021 — Февраль 20242 года 4 месяца', 'Всм-СервисМоскваПрограммист PythonBackend \nСтек технологий: Python, Django, Docker, PostgreSQL, Celery. \nФункционал:\n- разработка backend части сайта;\n- разработка сайта с подключённым телеграмм ботом (aiogram).\n- исправление различных багов в проекте.'], 'tags': ['Python', 'ООП', 'Git', 'PostgreSQL', 'SQL', 'Django Framework', 'Django', 'HTML', 'CSS', 'Bootstrap', 'Stripe', 'Docker', 'Jupiter', 'SQLite', 'Умение работать в команде', 'Паттерны проектирования', 'Английский язык', 'Умение разбираться в чужом коде', 'Linux', 'Базы данных'], 'link': 'https://hh.ru/resume/0de1b45d0008b61e070039ed1f6d6f4e4e4b43'}
# {'id': '5368145600030b31430039ed1f495a32686566', 'gender': 'Мужчина', 'age': '47 лет', 'date_of_birth': '18 мая 1976', 'about_me': 'В последние годы проходил обучение без возможности работать с 2015-2018.\r\nВ последнее время нахожусь в поисках работы.', 'education': ['Среднее специальное образование1995Ленинградский Обл. политехн. лицей г. Кингисеппаокончил полный курс профтехучилища, станочник широкого профиля'], 'language': [], 'job_search_status': 'Рассматривает предложения', 'city_of_residence': 'Ногинск', 'moving': 'готов к переезду (Москва, Россия)', 'business_trip': 'не готов к командировкам', 'name': 'Программист Python', 'salary': '', 'specialization_schedule': 'Специализации: Программист, разработчик Занятость: полная занятость, частичная занятость, проектная работа, стажировка График работы: полный день, гибкий график, удаленная работа', 'experience_all_period': 'Опыт работы 8 лет 7 месяцев', 'experience': ['Ноябрь 2015 — по настоящее время8 лет 7 месяцев', 'Индивидуальное предпринимательство / частная практика / фрилансПрограммист PythonПрактическое применение знаний и навыков программирования в области web, а также изучение новых технологий в сфере программирования (всё, что связано с python в основном).'], 'tags': ['JavaScript', 'Python', 'Linux', 'HTML5', 'SQL', 'CSS3', 'Git', 'SQLite', 'Django Framework', 'jQuery', 'PostgreSQL', 'Debian'], 'link': 'https://hh.ru/resume/5368145600030b31430039ed1f495a32686566'}
# {'id': 'd0f1b2650008cab3a10039ed1f625374695754', 'gender': 'Male', 'age': '38 years', 'date_of_birth': '16 December 1985', 'about_me': '+7(926)040-34-40\nTelegram: https://t.me/BruqwaWD\nEmail: 0403440@gmail.com\nGitHub: https://github.com/EgorShabalin\n\n\n\nI am passionate about developing robust back-end solutions. I am looking for a position of a Python back-end developer where I can utilize my skills and build upon my experience to help create powerful, efficient, and dynamic web applications.\n I enjoy problem-solving and exploring new technologies to improve my abilities as a developer. I am committed to continuously expanding my knowledge and skill set through continued learning opportunities and collaboration with experienced professionals in the field.', 'education': ['Higher education2006Высший институт управления, МоскваЮридический, Юриспруденция'], 'language': [], 'job_search_status': 'Actively searching for a job', 'city_of_residence': 'Moscow', 'moving': 'willing to relocate', 'business_trip': 'prepared for occasional business trips', 'name': 'Python developer', 'salary': '', 'specialization_schedule': 'Specializations: Programmer, developer Employment: full time, part time, project work, work placement Work schedule: full day, shift schedule, flexible schedule, remote working', 'experience_all_period': 'Work experience 8 months', 'experience': ['February 2024 — currently4 months', 'Индивидуальное предпринимательство / частная практика / фрилансPython developer(In Progress...) Integrating a self developed CRM system and automating business processes of the education company.\n\nhttps://github.com/EgorShabalin/crm_django.git', 'December 2023 — currently6 months', 'Индивидуальное предпринимательство / частная практика / фрилансPython developerReal Estate Agency Site\n\nI developed a multilingual website where you can purchase various property objects.\nThere is a search through all objects on website, feedback form, authentication to make personal favorites list and store the contacts, language switcher for 3 languages, etc.\n\nFor this project I used:\nDjango - models, views, urls, authenticating.\ndjango_use_email_as_username module for better user experience.\nPillow - to process the images.\nDocker - to make the project handy for deploy.\nI developed all the design in html, css and a little JavaScript.\n\nhttps://github.com/EgorShabalin/real_estate_site', 'December 2023 — February 20243 months', 'ProjectsPython developerProjects\n\nBlog site - made using Django. Authentication, posts, comments, likes and followers implemented already. Design made of clean HTML and CSS.\nhttps://github.com/EgorShabalin/blog_site\n\nChat bot for Telegram - made using Docker images of Python and Redis. It calls for ChatGPT API. Redis used to cache the history of conversation.\nhttps://github.com/EgorShabalin/chat_bot\n\nWagonloader - implementation of shelf bin packing algorithm. Made using Pillow to visualize the output.\nhttps://github.com/EgorShabalin/wagonloader_public\n\nPassword manager - GUI app made using Tkinter and SQLite, generates password of upper, lower letters, numbers and symbols. Then it can be stored in database.\nhttps://github.com/EgorShabalin/pasword_manager_tkinter', 'January 2022 — February 20222 months', 'Relabs.ruPython developerProject: online service to visualize equipment infrastructure and to search for new clients to connect for a cable maintenance company\n\nTo realize this project we used Docker images of Python, PostgreSQL, Redis and some custom SQL handling. FastAPI was used on the back-end.\n\nWe took a layer from pkk5.rosreestr.ru and added it on Yandex maps to visualize positioning of pillars and hubs on the map with information of property registry to automate gathering information of available customers addresses to connect.\n\nMy work was to create routers, models, their handling with database and all the tests for them.\n\nThe template we used: https://github.com/EgorShabalin/fastapi_templ ...
# {'id': 'f241842900057704840039ed1f314d56754168', 'gender': 'Мужчина', 'age': '24 года', 'date_of_birth': '14 апреля 2000', 'about_me': 'Оптимизация работы ОС Windows, владение аппаратной частью компьютера (железом).\n\nИмею навыки работы со следующими языками "С, C++, C#". \n\nБольше всего опыта работы с Python\n\nУмею разрабатывать телеграмм ботов, а так же специализируюсь на парсинге данных с различных сервисов.\n\nТак работаю с Linux, MySQL и PHP\n\nРазбираюсь в современной технике, компьютерах и гаджетах. \nЦелеустремленный, мобильный, пунктуальный, выносливый, порядочный, коммуникабельный‚ умею ориентироваться на карте и на местности.\nЕсть желание получать новые знания и применять их, а также хочу посмотреть Мир.\n\nУвлекаюсь астрономией и новыми технологиями.\nРост - 186см, вес - 78кг\nСудимость отсутствует. Не женат. Детей нет.\nПроживаю и зарегистрирован в г. Донецк', 'education': ['Неоконченное высшее образование2022Таганрогский технологический институт Южного федерального университета, ТаганрогИнститут компьютерных технологий и информационной безопасности (ИКТИБ), Информатика и вычислительная техника (заочное обучение)'], 'language': [], 'job_search_status': 'Не\xa0ищет работу', 'city_of_residence': 'Краснодар', 'moving': 'не готов к переезду', 'business_trip': 'не готов к командировкам', 'name': 'Программист Python', 'salary': '500 $ на руки', 'specialization_schedule': 'Специализации: Программист, разработчик Занятость: полная занятость, частичная занятость, проектная работа, стажировка График работы: полный день, сменный график, гибкий график, удаленная работа', 'experience_all_period': 'Опыт работы 6 лет 5 месяцев', 'experience': ['Январь 2018 — по настоящее время6 лет 5 месяцев', 'Индивидуальное предпринимательство / частная практика / фрилансПрограммист PythonРаботаю на фрилансе Python разработчиком. От простых задач до написания парсеров, телеграмм ботов и GUI приложений'], 'tags': ['Настройка ПК', 'Сборка ПК', 'Настройка сетевых подключений', 'Администрирование сетевого оборудования', 'Python', 'MySQL', 'PHP', 'Linux', 'Парсинг', 'Scripting'], 'link': 'https://hh.ru/resume/f241842900057704840039ed1f314d56754168'}
# {'id': 'b5bd1ef6000917804e0039ed1f483466796348', 'gender': 'Мужчина', 'age': '22 года', 'date_of_birth': '12 сентября 2001', 'about_me': 'Привет, я - python разработчик. Трудолюбивый и коммуникативный, не боюсь сложных задач. Ищу компанию, в которой смогу приносить пользу и расти как специалист. Открыт для предложений)', 'education': ['Высшее образование2023Уральский федеральный университет имени первого Президента России Б.Н. Ельцина, ЕкатеринбургИРИТ-РТФ, Информатика и вычислительная техника'], 'language': [], 'job_search_status': 'Рассматривает предложения', 'city_of_residence': 'Екатеринбург', 'moving': 'готов к переезду', 'business_trip': 'готов к командировкам', 'name': 'Разработчик Python', 'salary': '', 'specialization_schedule': 'Специализации: Программист, разработчик Занятость: полная занятость, частичная занятость, проектная работа, стажировка График работы: полный день, сменный график, гибкий график, удаленная работа', 'experience_all_period': 'Опыт работы 1 год 5 месяцев', 'experience': ['Июль 2023 — по настоящее время11 месяцев', 'СберЕкатеринбург, rabota.sber.ru/Финансовый сектор... Показать ещеРазработчик PythonРазработка инструментов для обработки больших данных.\n\nТехнологический стек:\n- Python\n- OpenCV, YOLO8\n- Pandas, NumPy\n- Linux, Ubuntu\n- Hive, Yarn\n\nОбязанности:\n- создание инструментов для нормализации и анализа большого объёма данных(numpy, pandas)\n- создание инструментов для анализа изображений (opencv, yolo8)\n- мониторинг и администрирование кластера (Apache Ambari)\n- создание инструментов для парсинга (selenium, requests, BeautifulSoup4)', 'Апрель 2022 — Август 20225 месяцев', 'ОКЕНИТСанкт-Петербург, okenit.ru/Информационные технологии, системная интеграция, интернет... Показать ещеРазработчик PythonСоздание сервиса для загрузки и анализа походных маршрутов.\n\nТехнологический стек:\n- Python\n- Django\n- Django rest framework\n- Djangorestframework-simplejwt\n- Java\n- Openstreetmaps\n\nОбязанности:\n- реализация rest api на drf\n- реализация гео-модуля\n- рефакторинг бэкенда\n- тестирование', 'Март 2022 — Июнь 20224 месяца', 'ЛАМАРТЕкатеринбург, lamart.site/Разработчик PythonПродуктовая разработка\n\nТехнологический стек:\n- GraphQL\n- Python\n- Redis\n- Celery\n- Docker\n- Flower\n\nОбязанности:\n- разработка telegram ботов\n- интеграции со сторонними сервисами\n- рефакторинг кода других разработчиков'], 'tags': ['Python', 'SQL', 'Django Framework', 'Git', 'Linux', 'Computer Vision', 'Английский язык', 'FastApi', 'Celery', 'Pandas', 'NumPy', 'YOLO8', 'requests', 'Atlassian Jira'], 'link': 'https://hh.ru/resume/b5bd1ef6000917804e0039ed1f483466796348'}
# {'id': 'abbff3eb00073b3a000039ed1f5332314a5056', 'gender': 'Мужчина', 'age': '28 лет', 'date_of_birth': '17 октября 1995', 'about_me': 'Быть программистом – значит решать сложные задачи. Мне нравится думать, трудиться над решением проблем, а еще создавать что-то полезное для людей.\nВ свободное от работы время люблю играть в волейбол, читать книги про психологию.', 'education': ['Высшее образование2021Казанский (Приволжский) федеральный университет, КазаньИнститут геологии и нефтегазовых технологий, Маркшейдерское дело (горный инженер)2019Казанский национальный исследовательский технологический университет, КазаньМеханический, Химическая технология ,магистр2017Казанский национальный исследовательский технологический университет, КазаньМеханический, Вакуумная и компрессорная техника физических установок'], 'language': [], 'job_search_status': 'Активно ищет работу', 'city_of_residence': 'Казань', 'moving': 'готов к переезду', 'business_trip': 'готов к командировкам', 'name': 'Python backend разработчик ', 'salary': '', 'specialization_schedule': 'Специализации: Программист, разработчик Занятость: полная занятость, частичная занятость, стажировка График работы: полный день, гибкий график, удаленная работа', 'experience_all_period': 'Опыт работы 2 года 5 месяцев', 'experience': ['Январь 2022 — по настоящее время2 года 5 месяцев', 'Индивидуальное предпринимательство / частная практика / фрилансИнформационные технологии, системная интеграция, интернет... Показать ещеПрограммист PythonЗанимался самообучением.\nПрошел курсы:\n1.Python разработка - с нуля до профессионала. Python 3\n2.Python в веб с нуля до создания приложений. Python + Django\n3.Основы Linux.\n4.Программирование на Golang.\nВходе обучения сделал с нуля несколько сайтов на Django\n1.Разработал портал, на котором каждый рекрутер сможет найти своего разработчика. Система поиска позволяет подобрать нужного специалиста по резюме, портфолио или описанию проектов; рейтинг проекта поможет оценить квалификацию, а мессенджер – послать оффер.\nСсылка https://github.com/irc95/itfinder\n2. Разработал сайт магазина игрушек с каталогом товаров и корзиной для покупок.\nСсылка https://github.com/irc95/ecommerce-shop\n'], 'tags': ['Django', 'Flask', 'Python', 'PostgreSQL', 'SQL', 'SQLite', 'ООП', 'Git', 'Docker', 'Linux', 'Bash', 'Golang', 'FastAPI', 'HTML', 'CSS', 'CSS3', 'Bootstrap', 'HTML5', 'C/C++'], 'link': 'https://hh.ru/resume/abbff3eb00073b3a000039ed1f5332314a5056'}
# {'id': 'a984f6330008851b520039ed1f6f635430414b', 'gender': 'Мужчина', 'age': '21 год', 'date_of_birth': '16 апреля 2003', 'about_me': 'Желание развиваться профессионально и постоянно погружаться в новые знания. Меня вдохновляет возможность наставлять, обучать и внедрять новые технологии в команде\n\nTelegram: elzar_zhoroev\nhttps://github.com/NElzar/', 'education': ['ОбразованиеСреднее образование'], 'language': [], 'job_search_status': 'Активно ищет работу', 'city_of_residence': 'Новосибирск', 'moving': 'готов к переезду', 'business_trip': 'готов к командировкам', 'name': 'Python Developer', 'salary': '', 'specialization_schedule': 'Специализации: Программист, разработчик Занятость: полная занятость График работы: полный день', 'experience_all_period': 'Опыт работы 3 года 4 месяца', 'experience': ['Ноябрь 2022 — по настоящее время1 год 7 месяцев', 'Бюро СучковаТюмень, bureausuchkov.com/СМИ, маркетинг, реклама, BTL, PR, дизайн, продюсирование... Показать ещеPython Developer● Разработка и поддержка сайта DeLean.\n● Разработка с нуля backend части сайта balancetowers.ru.\n● Создание Telegram ботов.\n\n\nСтек технологий: \n• Python 3\n• Django\n• REST API\n• Docker\n• PostgreSQL\n• Celery\n• Redis\n• RabbitMQ.', 'Апрель 2022 — Август 20225 месяцев', 'At control - smart watch (Проектная работа)Python Developer● Разработка умных детских часов с функцией отслеживания местоположения и другими возможностями.\n● Тестирование проекта с использованием pytest.\n\n\nСтек технологий:\n• Python 2\n• Django\n• Pytest\n• Mock\n• Docker', 'Декабрь 2021 — Июнь 20227 месяцев', 'РосстрахНовосибирск, rosstrah.ru/Python DeveloperСтрахование ТС ОСАГО/КАСКО\n\n●Разработка микросервисов для скрапинга данных.\n\n\nСтек технологий:\n• Python 3\n• Django\n• Aiohttp\n• AsyncIO\n• Multithreading \n• Docker', 'Март 2021 — Апрель 20221 год 2 месяца', 'Fast delivery Python Developer● Разработка системы сбора данных с партнерских платформ.\n● Интеграции в Django проект.\n\nСтек технологий:\n• Python 3\n• Django\n• Multithreading \n• Docker\n• rеquest  \n', 'Декабрь 2020 — Февраль 20213 месяца', 'Индивидуальное предпринимательство / частная практика / фрилансPython Developer● Разработка конструктора чат ботов для WhatsApp.\n\nСтек:\n• Python 3\n• Django\n• Selenium'], 'tags': ['Асинхронное программирование', 'GitHub', 'REST API', 'Celery', 'RabbitMQ', 'PostgreSQL', 'REST', 'Redis', 'Django Framework', 'Python', 'CSS', 'HTML', 'XML', 'Selenium', 'XPath', 'aiohttp', 'AsyncIO', 'Git', 'pytest', 'mock'], 'link': 'https://hh.ru/resume/a984f6330008851b520039ed1f6f635430414b'}
# {'id': 'e7b4bf0a0008e381da0039ed1f38766a646b64', 'gender': 'Мужчина', 'age': '23 года', 'date_of_birth': '9 декабря 2000', 'about_me': 'В поиске работы / стажировки.\nМои навыки:\n•\tРазработка приложений на Python (frameworks: Django, Django-REST, Flask, PyTelegramBotApi, Aiogram, bs4, Selenium, PyGobject)\n• Знание Docker и docker-compose;\n•\tЗнание языка запросов PostgreSQL, MySQL, SQLite\n•\tЗнание языка разметки HTML + CSS\n•\tОпыт создания виртуальной частной сети (VPN)\n•\tУверенный пользователь Linux, Windows, Android\n•\tОпыт администрирования: развертывание приложения на VPS.\n•\tНавык слепой печати\n•\tЗнание Git-Console (https://github.com/damiraminov1)', 'education': ['Высшее образование (Магистр)2025Уральский государственный университет путей сообщения, ЕкатеринбургЭлектротехнический факультет, Информационная безопасность телекоммуникационных систем (специалист по защите информации)2023Уральский государственный университет путей сообщения, ЕкатеринбургЭлектротехнический факультет, Информационные системы и технологии'], 'language': [], 'job_search_status': 'Не\xa0ищет работу', 'city_of_residence': 'Екатеринбург', 'moving': 'м. Чкаловская, не готов к переезду', 'business_trip': 'не готов к командировкам', 'name': 'Программист Python', 'salary': '', 'specialization_schedule': 'Специализации: Программист, разработчик Занятость: полная занятость График работы: полный день', 'experience_all_period': 'Опыт работы 2 года 4 месяца', 'experience': ['Сентябрь 2023 — по настоящее время9 месяцев', '"Пэйкон-Технолоджи", ОООПрограммист PythonРазработка программного обеспечения на Python. PyGobject, Gtk+ 3', 'Апрель 2022 — Сентябрь 20231 год 6 месяцев', 'LamArt, ОООЕкатеринбург, lamart.site/Программист PythonPython-разработка программного обеспечения. Django Rest Framework', 'Декабрь 2021 — Январь 20222 месяца', 'Maxima, ОООКазань, maxima.life/Информационные технологии, системная интеграция, интернет... Показать ещеНаставник онлайн курса Python-разработкиОтветы на вопросы учеников курса в чате. Проверка домашних заданий. Проведение онлайн консультаций.'], 'tags': ['Ответственность', 'Настойчивость', ' Python', 'PostgreSQL', 'Git', 'HTML5', 'CSS3', 'Linux', 'Flask', 'SQLite', 'ООП', 'Docker', 'Django Framework', 'Django REST', 'Django Rest Framework', 'REST API'], 'link': 'https://hh.ru/resume/e7b4bf0a0008e381da0039ed1f38766a646b64'}
# {'id': 'b20968c600072c00690039ed1f696f39643366', 'gender': 'Мужчина', 'age': '23 года', 'date_of_birth': '13 мая 2000', 'about_me': 'Опрятный, общительный, оптимист. Легко обучаемый. Продолжаю постоянно совершенствовать свои навыки программирования и менеджмента.', 'education': ['Неоконченное высшее образование2023School21Developer2022Московский государственный технический университет им. Н.Э. Баумана, МоскваСпециальное машиностроение , Мехатроника и роботехника2020Курсы Learn pythonPython developer'], 'language': [], 'job_search_status': 'Активно ищет работу', 'city_of_residence': 'Москва', 'moving': 'готов к переезду', 'business_trip': 'готов к командировкам', 'name': 'Программист Python', 'salary': '', 'specialization_schedule': 'Специализации: Программист, разработчик Занятость: полная занятость График работы: полный день, удаленная работа', 'experience_all_period': 'Опыт работы 3 года 3 месяца', 'experience': ['Май 2023 — по настоящее время1 год 1 месяц', 'Independent contractorPython developerРазрабатываю сервис для сборы статистики с 360 стран', 'Февраль 2021 — Март 20232 года 2 месяца', 'MirPython developerЗанимаемся разработкой приложения для знакомств.'], 'tags': ['Bootstrap', 'Clean Architecture', 'SOLID', 'ООП', 'Web Application Development', 'C/C++', 'Pandas', 'MS SQL Server', ' Python', 'Flask', 'SQL', 'Git', 'Linux', 'PostgreSQL', 'FastAPI', 'aiohttp', 'ORM', 'Docker', 'Celery', 'Docker-compose', 'Redis', 'RabbitMQ', 'ClickHouse', 'Gitlab'], 'link': 'https://hh.ru/resume/b20968c600072c00690039ed1f696f39643366'}

# %%
# Извлекаем информацию из файла с парсингом резюме при помощи pandas
data_res_resume = pd.read_csv('/content/drive/MyDrive/Practice2/result_resumes.csv')

# %%
data_res_resume
# Out:
#                                        id   gender       age  \
# 0  564d2d4d00090608d70039ed1f497074436c4e  Мужчина    35 лет
# 1  0de1b45d0008b61e070039ed1f6d6f4e4e4b43  Мужчина    21 год
# 2  5368145600030b31430039ed1f495a32686566  Мужчина    47 лет
# 3  d0f1b2650008cab3a10039ed1f625374695754     Male  38 years
# 4  f241842900057704840039ed1f314d56754168  Мужчина   24 года
# 5  b5bd1ef6000917804e0039ed1f483466796348  Мужчина   22 года
# 6  abbff3eb00073b3a000039ed1f5332314a5056  Мужчина    28 лет
# 7  a984f6330008851b520039ed1f6f635430414b  Мужчина    21 год
# 8  e7b4bf0a0008e381da0039ed1f38766a646b64  Мужчина   23 года
# 9  b20968c600072c00690039ed1f696f39643366  Мужчина   23 года
#
#                                             about_me  \
# 0                                                NaN
# 1  Имею опыт разработки в различных сферах на Pyt...
# 2  В последние годы проходил обучение без возможн...
# 3  +7(926)040-34-40\nTelegram: https://t.me/Bruqw...
# 4  Оптимизация работы ОС Windows, владение аппара...
# 5  Привет, я - python разработчик. Трудолюбивый и...
# 6  Быть программистом – значит решать сложные зад...
# 7  Желание развиваться профессионально и постоянн...
# 8  В поиске работы / стажировки.\nМои навыки:\n•\...
# 9  Опрятный, общительный, оптимист. Легко обучаем...
#
#                                            education language  \
# 0                 ['ОбразованиеСреднее образование']       []
# 1  ['Высшее образование2025Российский университет...       []
# 2  ['Среднее специальное образование1995Ленинград...       []
# 3  ['Higher education2006Высший институт управлен...       []
# 4  ['Неоконченное высшее образование2022Таганрогс...       []
# 5  ['Высшее образование2023Уральский федеральный ...       []
# 6  ['Высшее образование2021Казанский (Приволжский...       []
# 7                 ['ОбразованиеСреднее образование']       []
# 8  ['Высшее образование (Магистр)2025Уральский го...       []
# 9  ['Неоконченное высшее образование2023School21D...       []
#
#       date_of_birth             job_search_status city_of_residence  \
# 0     15 марта 1989                Не ищет работу       Новосибирск
# 1  13 сентября 2002                Не ищет работу            Москва
# 2       18 мая 1976     Рассматривает предложения           Ногинск
# 3  16 December 1985  Actively searching for a job            Moscow
# 4    14 апреля 2000                Не ищет работу         Краснодар
# 5  12 сентября 2001     Рассматривает предложения      Екатеринбург
# 6   17 октября 1995           Активно ищет работу            Казань
# 7    16 апреля 2003           Активно ищет работу       Новосибирск
# 8    9 декабря 2000                Не ищет работу      Екатеринбург
# 9       13 мая 2000           Активно ищет работу            Москва
#
#                                       moving  \
# 0  готов к переезду (Россия, Другие регионы)
# 1               м. ВДНХ, не готов к переезду
# 2          готов к переезду (Москва, Россия)
# 3                        willing to relocate
# 4                        не готов к переезду
# 5                           готов к переезду
# 6                           готов к переезду
# 7                           готов к переезду
# 8         м. Чкаловская, не готов к переезду
# 9                           готов к переезду
#
#                             business_trip                         name  \
# 0                   готов к командировкам      Python junior developer
# 1                не готов к командировкам           Python-разработчик
# 2                не готов к командировкам           Программист Python
# 3  prepared for occasional business trips             Python developer
# 4                не готов к командировкам           Программист Python
# 5                   готов к командировкам           Разработчик Python
# 6                   готов к командировкам  Python backend разработчик
# 7                   готов к командировкам             Python Developer
# 8                не готов к командировкам           Программист Python
# 9                   готов к командировкам           Программист Python
#
#           salary                            specialization_schedule  \
# 0            NaN  Специализации: Программист, разработчик Занято...
# 1            NaN  Специализации: Программист, разработчик Занято...
# 2            NaN  Специализации: Программист, разработчик Занято...
# 3            NaN  Specializations: Programmer, developer Employm...
# 4  500 $ на руки  Специализации: Программист, разработчик Занято...
# 5            NaN  Специализации: Программист, разработчик Занято...
# 6            NaN  Специализации: Программист, разработчик Занято...
# 7            NaN  Специализации: Программист, разработчик Занято...
# 8            NaN  Специализации: Программист, разработчик Занято...
# 9            NaN  Специализации: Программист, разработчик Занято...
#
#           experience_all_period  \
# 0  Опыт работы 2 года 7 месяцев
# 1   Опыт работы 2 года 4 месяца
# 2   Опыт работы 8 лет 7 месяцев
# 3      Work experience 8 months
# 4   Опыт работы 6 лет 5 месяцев
# 5   Опыт работы 1 год 5 месяцев
# 6  Опыт работы 2 года 5 месяцев
# 7   Опыт работы 3 года 4 месяца
# 8   Опыт работы 2 года 4 месяца
# 9   Опыт работы 3 года 3 месяца
#
#                                           experience  \
# 0  ['Ноябрь 2021 — по настоящее время2 года 7 мес...
# 1  ['Ноябрь 2021 — Февраль 20242 года 4 месяца', ...
# 2  ['Ноябрь 2015 — по настоящее время8 лет 7 меся...
# 3  ['February 2024 — currently4 months', 'Индивид...
# 4  ['Январь 2018 — по настоящее время6 лет 5 меся...
# 5  ['Июль 2023 — по настоящее время11 месяцев', '...
# 6  ['Январь 2022 — по настоящее время2 года 5 мес...
# 7  ['Ноябрь 2022 — по настоящее время1 год 7 меся...
# 8  ['Сентябрь 2023 — по настоящее время9 месяцев'...
# 9  ['Май 2023 — по настоящее время1 год 1 месяц',...
#
#                                                 tags  \
# 0  ['Амбициозность', 'Python', 'PostgreSQL', 'Git...
# 1  ['Python', 'ООП', 'Git', 'PostgreSQL', 'SQL', ...
# 2  ['JavaScript', 'Python', 'Linux', 'HTML5', 'SQ...
# 3  ['Python', 'SQL', 'Django Framework', 'English...
# 4  ['Настройка ПК', 'Сборка ПК', 'Настройка сетев...
# 5  ['Python', 'SQL', 'Django Framework', 'Git', '...
# 6  ['Django', 'Flask', 'Python', 'PostgreSQL', 'S...
# 7  ['Асинхронное программирование', 'GitHub', 'RE...
# 8  ['Ответственность', 'Настойчивость', ' Python'...
# 9  ['Bootstrap', 'Clean Architecture', 'SOLID', '...
#
#                                                 link
# 0  https://hh.ru/resume/564d2d4d00090608d70039ed1...
# 1  https://hh.ru/resume/0de1b45d0008b61e070039ed1...
# 2  https://hh.ru/resume/5368145600030b31430039ed1...
# 3  https://hh.ru/resume/d0f1b2650008cab3a10039ed1...
# 4  https://hh.ru/resume/f241842900057704840039ed1...
# 5  https://hh.ru/resume/b5bd1ef6000917804e0039ed1...
# 6  https://hh.ru/resume/abbff3eb00073b3a000039ed1...
# 7  https://hh.ru/resume/a984f6330008851b520039ed1...
# 8  https://hh.ru/resume/e7b4bf0a0008e381da0039ed1...
# 9  https://hh.ru/resume/b20968c600072c00690039ed1...
